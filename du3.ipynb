# %%
import nltk

# read file
with open('ebook.txt', 'r', encoding="utf8") as f:
    text = f.read()

# split to sentences, and split sentences to tokens
sentences = nltk.sent_tokenize(text)
tokens_in_sentences = [nltk.word_tokenize(sent) for sent in sentences]

# remove punctuation
 # does not remove utf punc, to do so use e.g. https://stackoverflow.com/questions/11066400/remove-punctuation-from-unicode-formatted-strings
tokens_in_sentences_nopunc = []
from string import punctuation
for token_sentence in tokens_in_sentences:
    tokens_in_sentences_nopunc.append([token for token in token_sentence if token not in punctuation])

# %% [markdown]
# ## POS tagging

# %%
# tag words in sentences first
tagged = [nltk.pos_tag(tag) for tag in tokens_in_sentences_nopunc]

# %% [markdown]
# ## NER with entity classification (using nltk.ne_chunk)

# %%
 # use nltk.ne_chunk ("_sents" is for sentences) - returns tree structure per sentence
chunked_sentences = nltk.ne_chunk_sents(tagged, binary=False)

for s in chunked_sentences:
    print(s)
# Out:
# (S
#   (PERSON Front/NNP)
#   (PERSON Matter/NNP Preface/NNP Foundations/NNP Problem/NNP)
#   Statement/NNP
#   Our/PRP$
#   Simulation/NNP
#   Application/NNP
#   Soapbox/NNP
#   on/IN
#   (ORGANIZATION
#     Use/NNP
#     Cases/NNP
#     Solution/NNP
#     Approach/NNP
#     Methodology/NNP
#     Technique/NNP)
#   and/CC
#   (ORGANIZATION Process/NNP Additional/NNP)
#   Topics/NNP
#   Non-Functional/JJ
#   Requirements/NNP
#   Deliverables/NNP
#   Roulette/NNP
#   This/DT
#   part/NN
#   describes/VBZ
#   the/DT
#   game/NN
#   of/IN
#   (GPE Roulette/NNP))
# (S
#   (GPE Roulette/NNP)
#   is/VBZ
#   the/DT
#   game/NN
#   with/IN
#   the/DT
#   big/JJ
#   wheel/NN)
# (S
#   They/PRP
#   spin/VBP
#   the/DT
#   wheel/NN
#   toss/NN
#   in/IN
#   a/DT
#   marble/JJ
#   and/CC
#   wait/NN
#   for/IN
#   the/DT
#   wheel/NN
#   to/TO
#   stop/VB
#   spinning/NN)
# (S
#   (GPE Roulette/NNP)
#   is/VBZ
#   –/NNP
#   essentially/RB
#   –/VBZ
#   a/DT
#   stateless/JJ
#   game/NN
#   with/IN
#   numerous/JJ
#   bets/NNS
#   and/CC
#   a/DT
#   very/RB
#   simple/JJ
#   process/NN
#   for/IN
#   game/NN
#   play/NN)
# (S
#   The/DT
#   chapters/NNS
#   of/IN
#   this/DT
#   part/NN
#   present/VBZ
#   the/DT
#   details/NNS
#   on/IN
#   the/DT
#   game/NN
#   an/DT
#   overview/NN
#   of/IN
#   the/DT
#   solution/NN
#   and/CC
#   a/DT
#   series/NN
#   of/IN
#   sixteen/JJ
#   exercises/NNS
#   to/TO
#   build/VB
#   a/DT
#   complete/JJ
#   simulation/NN
#   of/IN
#   the/DT
#   game/NN
#   plus/CC
#   a/DT
#   variety/NN
#   of/IN
#   betting/VBG
#   strategies/NNS)
# (S
#   Each/DT
#   exercise/NN
#   chapter/NN
#   builds/NNS
#   at/IN
#   least/JJS
#   one/CD
#   class/NN
#   plus/CC
#   unit/NN
#   tests/NNS
#   in/IN
#   some/DT
#   cases/NNS
#   this/DT
#   includes/VBZ
#   rework/NN
#   of/IN
#   previous/JJ
#   deliverables/NNS)
# (S
#   (PERSON Roulette/NNP)
#   (PERSON Details/NNP Roulette/NNP)
#   Game/NNP
#   Available/NNP
#   Bets/NNP
#   in/IN
#   (GPE Roulette/NNP)
#   Some/DT
#   Betting/NNP
#   Strategies/NNPS
#   (PERSON Roulette/NNP Details/NNP Questions/NNP)
#   and/CC
#   (ORGANIZATION Answers/NNP Roulette/NNP Solution/NNP Overview/NNP)
#   Preliminary/NNP
#   Survey/NNP
#   of/IN
#   (PERSON Classes/NNP)
#   Preliminary/NNP
#   (PERSON Roulette/NNP Class/NNP Structure/NNP)
#   A/NNP
#   Walkthrough/NNP
#   of/IN
#   (PERSON Roulette/NNP Roulette/NNP Solution/NNP Questions/NNP)
#   and/CC
#   (ORGANIZATION Answers/NNP Outcome/NNP)
#   Class/NNP
#   Outcome/NNP
#   Analysis/NNP
#   Design/NNP
#   Decision/NNP
#   –/NNP
#   Object/NNP
#   Identity/NNP
#   Looking/NNP
#   Forward/NNP
#   Outcome/NNP
#   Design/NNP
#   Outcome/NNP
#   Deliverables/NNP
#   Message/NNP
#   Formatting/NNP
#   Bin/NNP
#   Class/NNP
#   Bin/NNP
#   Analysis/NNP
#   Design/NNP
#   Decision/NNP
#   –/NNP
#   Choosing/VBG
#   A/DT
#   (ORGANIZATION Collection/NNP Wrap/NNP)
#   vs/NN)
# (S
#   Extend/VB
#   a/DT
#   (ORGANIZATION Collection/NNP Bin/NNP Questions/NNP)
#   and/CC
#   (ORGANIZATION Answers/NNP Bin/NNP)
#   Design/NNP
#   Bin/NNP
#   Deliverables/NNP
#   Wheel/NNP
#   Class/NNP
#   Wheel/NNP
#   Analysis/NNP
#   Wheel/NNP
#   Design/NNP
#   Test/NNP
#   Setup/NNP
#   Wheel/NNP
#   Deliverables/NNP
#   Bin/NNP
#   Builder/NNP
#   Class/NNP
#   Bin/NNP
#   Builder/NNP
#   Analysis/NNP
#   Bin/NNP
#   Builder/NNP
#   Algorithms/NNP
#   BinBuilder/NNP
#   Design/NNP
#   Bin/NNP
#   Builder/NNP
#   Deliverables/NNP
#   Internationalization/NNP
#   and/CC
#   (ORGANIZATION Localization/NNP Roulette/NNP Bet/NNP)
#   Class/NNP
#   (PERSON Roulette/NNP Bet/NNP Analysis/NNP)
#   Design/NNP
#   Decision/NNP
#   –/NNP
#   Create/NNP
#   or/CC
#   (ORGANIZATION Locate/NNP)
#   an/DT
#   Outcome/NNP
#   (PERSON Roulette/NNP Bet/NNP Questions/NNP)
#   and/CC
#   (ORGANIZATION Answers/NNP Roulette/NNP Bet/NNP)
#   Design/NNP
#   (PERSON
#     Roulette/NNP
#     Bet/NNP
#     Deliverables/NNP
#     Roulette/NNP
#     Table/NNP)
#   Class/NNP
#   (PERSON Roulette/NNP Table/NNP Analysis/NNP)
#   (ORGANIZATION InvalidBet/NNP Exception/NNP)
#   Design/NNP
#   (PERSON Roulette/NNP Table/NNP)
#   Design/NNP
#   (PERSON Roulette/NNP Table/NNP Deliverables/NNP Roulette/NNP)
#   Game/NNP
#   Class/NNP
#   (PERSON Roulette/NNP Game/NNP Analysis/NNP Passenger57/NNP)
#   Design/NNP
#   (PERSON Roulette/NNP Game/NNP)
#   Design/NNP
#   (PERSON Roulette/NNP Game/NNP Questions/NNP)
#   and/CC
#   (ORGANIZATION Answers/NNP Roulette/NNP)
#   Game/NNP
#   Deliverables/NNP
#   Appendix/NNP
#   (PERSON Roulette/NNP Variations/NNP Review/NNP)
#   of/IN
#   (ORGANIZATION Testability/NNP Test/NNP)
#   Scaffolding/VBG
#   Test-Driven/NNP
#   Design/NNP
#   Capturing/NNP
#   Pseudo-Radom/NNP
#   Data/NNP
#   Testability/NNP
#   Questions/NNP
#   and/CC
#   (ORGANIZATION
#     Answers/NNP
#     Testability/NNP
#     Deliverables/NNP
#     Appendix/NNP)
#   On/IN
#   (PERSON Random/NNP Numbers/NNP Player/NNP)
#   Class/NNP
#   Roulette/NNP
#   Player/NNP
#   Analysis/NNP
#   Player/NNP
#   Design/NNP
#   Martingale/NNP
#   Player/NNP
#   Design/NNP
#   Player/NNP
#   Deliverables/NNP
#   Overall/NNP
#   Simulation/NNP
#   Control/NNP
#   Simulation/NNP
#   Analysis/NNP
#   Statistical/NNP
#   Summary/NNP
#   Simulator/NNP
#   Design/NNP
#   Player/NNP
#   (PERSON Rework/NNP Simulation/NNP Control/NNP Deliverables/NNP)
#   SevenReds/NNP
#   Player/NNP
#   Class/NNP
#   SevenReds/NNP
#   Player/NNP
#   Analysis/NNP
#   Soapbox/NNP
#   on/IN
#   (ORGANIZATION Composition/NNP)
#   SevenReds/NNP
#   Design/NNP
#   Player/NNP
#   (PERSON Rework/NNP Game/NNP Rework/NNP Table/NNP Rework/NNP)
#   SevenReds/NNP
#   Player/NNP
#   Deliverables/NNP
#   Statistical/NNP
#   Measures/NNP
#   Statistical/NNP
#   Analysis/NNP
#   Some/DT
#   Foundations/NNP
#   Statistical/NNP
#   Algorithms/NNP
#   IntegerStatistics/NNP
#   Design/NNP
#   Statistics/NNPS
#   (PERSON Deliverables/NNP Random/NNP Player/NNP)
#   Class/NNP
#   Random/NNP
#   Player/NNP
#   Analysis/NNP
#   Random/NNP
#   Player/NNP
#   Design/NNP
#   Random/NNP
#   Player/NNP
#   Deliverables/NNP
#   Player/NNP
#   1-3-2-6/JJ
#   Class/NNP
#   Player/NNP
#   1-3-2-6/JJ
#   Analysis/NN
#   On/IN
#   Polymorphism/NNP
#   Player/NNP
#   1-3-2-6/JJ
#   Questions/NNS
#   and/CC
#   (ORGANIZATION Answers/NNP Player1326/NNP)
#   State/NNP
#   Design/NNP
#   Player1326/NNP
#   No/NNP
#   Wins/NNP
#   Design/NNP
#   Player1326/NNP
#   One/NNP
#   Win/NNP
#   Design/NNP
#   Player1326/NNP
#   Two/CD
#   Wins/NNP
#   Design/NNP
#   Player1326/NNP
#   Three/NNP
#   Wins/NNP
#   Player1326/NNP
#   Design/NNP
#   Player/NNP
#   1-3-2-6/JJ
#   (PERSON Deliverables/NNP Advanced/NNP Exercise/NNP)
#   –/NNP
#   Refactoring/NNP
#   Advanced/NNP
#   Exercise/NNP
#   –/NNP
#   Less/NNP
#   Object/NNP
#   Creation/NNP
#   Cancellation/NNP
#   Player/NNP
#   Class/NNP
#   Cancellation/NNP
#   Player/NNP
#   Analysis/NNP
#   PlayerCancellation/NNP
#   Design/NNP
#   Cancellation/NNP
#   Player/NNP
#   Deliverables/NNP
#   Fibonacci/NNP
#   Player/NNP
#   Class/NNP
#   Fibonacci/NNP
#   Player/NNP
#   Analysis/NNP
#   PlayerFibonacci/NNP
#   Design/NNP
#   Fibonacci/NNP
#   Player/NNP
#   Deliverables/NNP
#   Conclusion/NNP
#   Exploration/NNP
#   The/DT
#   (ORGANIZATION SOLID/NNP Principles/NNP)
#   Other/JJ
#   Design/NNP
#   (PERSON Patterns/NNP Craps/NNP)
#   This/DT
#   part/NN
#   describes/VBZ
#   parts/NNS
#   of/IN
#   the/DT
#   more/RBR
#   complex/JJ
#   game/NN
#   of/IN
#   (GPE Craps/NNP))
# (S (GPE Craps/NNP) is/VBZ played/VBN with/IN dice/NN)
# (S
#   A/DT
#   player/NN
#   throws/VBZ
#   the/DT
#   dice/NN
#   sometimes/VBZ
#   it/PRP
#   ’/NNP
#   s/VBD
#   an/DT
#   immediate/JJ
#   win/NN
#   or/CC
#   loss/NN)
# (S
#   Other/JJ
#   times/NNS
#   the/DT
#   number/NN
#   on/IN
#   the/DT
#   dice/NN
#   become/VBD
#   the/DT
#   “/JJ
#   point/NN
#   ”/NN
#   and/CC
#   you/PRP
#   contine/VBP
#   throwing/VBG
#   dice/NN
#   until/IN
#   you/PRP
#   make/VBP
#   your/PRP$
#   point/NN
#   or/CC
#   crap/NN
#   out/RP)
# (S
#   (GPE Craps/NNP)
#   is/VBZ
#   a/DT
#   game/NN
#   with/IN
#   two/CD
#   states/NNS
#   and/CC
#   a/DT
#   number/NN
#   of/IN
#   state-change/NN
#   rules/NNS)
# (S
#   It/PRP
#   has/VBZ
#   a/DT
#   variety/NN
#   betting/VBG
#   alternatives/NNS
#   some/DT
#   of/IN
#   which/WDT
#   are/VBP
#   quite/RB
#   complex/JJ)
# (S
#   The/DT
#   chapters/NNS
#   of/IN
#   this/DT
#   part/NN
#   presents/VBZ
#   the/DT
#   details/NNS
#   on/IN
#   the/DT
#   game/NN
#   an/DT
#   overview/NN
#   of/IN
#   the/DT
#   solution/NN
#   and/CC
#   a/DT
#   series/NN
#   of/IN
#   eleven/JJ
#   exercises/NNS
#   to/TO
#   build/VB
#   a/DT
#   complete/JJ
#   simulation/NN
#   of/IN
#   the/DT
#   game/NN
#   with/IN
#   a/DT
#   variety/NN
#   of/IN
#   betting/VBG
#   strategies/NNS)
# (S
#   The/DT
#   exercises/NNS
#   in/IN
#   this/DT
#   part/NN
#   are/VBP
#   more/RBR
#   advanced/JJ
#   unlike/IN
#   Roulette/NNP
#   we/PRP
#   will/MD
#   often/RB
#   combine/VB
#   several/JJ
#   classes/NNS
#   into/IN
#   a/DT
#   single/JJ
#   batch/NN
#   of/IN
#   deliverables/NNS)
# (S
#   There/EX
#   are/VBP
#   several/JJ
#   examples/NNS
#   of/IN
#   rework/NN
#   in/IN
#   this/DT
#   part/NN
#   some/DT
#   of/IN
#   them/PRP
#   quite/RB
#   extensive/JJ)
# (S
#   This/DT
#   kind/NN
#   of/IN
#   rework/NN
#   reflects/VBZ
#   three/CD
#   more/JJR
#   advanced/JJ
#   scenarios/NNS
#   refactoring/VBG
#   to/TO
#   generalize/VB
#   and/CC
#   add/VB
#   features/NNS
#   renaming/VBG
#   to/TO
#   rationalize/VB
#   the/DT
#   architecture/NN
#   and/CC
#   refactoring/VBG
#   to/TO
#   extract/VB
#   features/NNS)
# (S
#   Each/DT
#   of/IN
#   these/DT
#   is/VBZ
#   the/DT
#   result/NN
#   of/IN
#   learning/VBG
#   they/PRP
#   are/VBP
#   design/JJ
#   issues/NNS
#   that/WDT
#   can/MD
#   ’/VB
#   t/VB
#   easily/RB
#   be/VB
#   located/VBN
#   or/CC
#   explained/VBN
#   in/IN
#   advance/NN)
# (S
#   (PERSON Craps/NNP)
#   (PERSON Details/NNP Craps/NNP)
#   Game/NNP
#   Creating/NNP
#   A/NNP
#   Dice/NNP
#   (PERSON Frequency/NNP Distribution/NNP Available/NNP Bets/NNP)
#   Some/DT
#   Betting/NNP
#   Strategies/NNPS
#   (PERSON Wrong/NNP Betting/NNP Craps/NNP Solution/NNP Overview/NNP)
#   Preliminary/NNP
#   Survey/NNP
#   of/IN
#   (PERSON Classes/NNP)
#   Preliminary/NNP
#   (PERSON Craps/NNP Class/NNP Structure/NNP)
#   A/NNP
#   Walkthrough/NNP
#   of/IN
#   (PERSON Craps/NNP Craps/NNP Solution/NNP Questions/NNP)
#   and/CC
#   (ORGANIZATION Answers/NNP Outcome/NNP)
#   Class/NNP
#   Outcome/NNP
#   Analysis/NNP
#   Fractional/NNP
#   Odds/NNP
#   Design/NNP
#   Optional/NNP
#   Parameter/NNP
#   Implementation/NNP
#   Technique/NNP
#   Outcome/NNP
#   (PERSON Rework/NNP Outcome/NNP Deliverables/NNP Throw/NNP)
#   Class/NNP
#   Throw/NNP
#   Analysis/NNP
#   The/DT
#   (ORGANIZATION Wrap/NNP)
#   vs/NN)
# (S
#   (PERSON Extend/NNP)
#   (ORGANIZATION Question/NNP Throw/NNP)
#   Design/NNP
#   Natural/NNP
#   Throw/NNP
#   Design/NNP
#   (PERSON Craps/NNP Throw/NNP)
#   Design/NNP
#   Eleven/NNP
#   Throw/NNP
#   Design/NNP
#   Point/NNP
#   Throw/NNP
#   Design/NNP
#   (PERSON Craps/NNP Game/NNP)
#   Design/NNP
#   Throw/NNP
#   Deliverables/NNP
#   Dice/NNP
#   Class/NNP
#   Dice/NNP
#   Analysis/NNP
#   Throw/NNP
#   (PERSON Rework/NNP Dice/NNP)
#   Design/NNP
#   Dice/NNP
#   Deliverables/NNP
#   Dice/NNP
#   Optimization/NNP
#   Throw/NNP
#   Builder/NNP
#   Class/NNP
#   Throw/NNP
#   Builder/NNP
#   Analysis/NNP
#   Outcomes/NNP
#   with/IN
#   (PERSON Variable/NNP Odds/NNP)
#   Refactoring/VBG
#   The/DT
#   (ORGANIZATION Outcome/NNP Hierarchy/NNP Soapbox/NNP)
#   on/IN
#   (ORGANIZATION Subclasses/NNP Soapbox/NNP)
#   on/IN
#   (ORGANIZATION Architecture/NNP Throw/NNP Builder/NNP Questions/NNP)
#   and/CC
#   (ORGANIZATION Answers/NNP Soapbox/NNP)
#   on/IN
#   Justification/NNP
#   Design/NNP
#   Light/NNP
#   Design/NNP
#   Heavy/NNP
#   Common/NNP
#   Design/NNP
#   Throw-Builder/NNP
#   Deliverables/NNP
#   Bet/NNP
#   Class/NNP
#   Bet/NNP
#   Analysis/NNP
#   Bet/NNP
#   Rework/NNP
#   (ORGANIZATION CommissionBet/NNP)
#   Design/NNP
#   Bet/NNP
#   Deliverables/NNP
#   (PERSON Craps/NNP Table/NNP)
#   Class/NNP
#   Craps/NNP
#   Table/NNP
#   Analysis/NNP
#   Design/NNP
#   Decision/NNP
#   –/NNP
#   Table/NNP
#   vs./FW
#   Game/NNP
#   Responsibility/NNP
#   Design/NNP
#   Decision/NNP
#   –/NNP
#   Allowable/NNP
#   Outcomes/NNP
#   Design/NNP
#   Decision/NNP
#   –/NNP
#   Domain/NNP
#   of/IN
#   (PERSON Allowed/NNP Bets/NNP Handling/NNP Working/NNP Bets/NNP)
#   CrapsGame/NNP
#   Stub/NNP
#   (PERSON Craps/NNP Table/NNP)
#   Design/NNP
#   (PERSON Craps/NNP Table/NNP Deliverables/NNP)
#   CrapsGame/NNP
#   Class/NNP
#   Craps/NNP
#   Game/NNP
#   Analysis/NNP
#   Design/NNP
#   Decision/NNP
#   –/NNP
#   Win/NNP
#   Lose/NNP
#   Wait/NNP
#   Additional/NNP
#   Craps/NNP
#   Design/NNP
#   (PERSON Craps/NNP Game/NNP)
#   Implementation/NNP
#   (PERSON Steps/NNP Throw/NNP Rework/NNP)
#   ThrowBuilder/NNP
#   (PERSON Rework/NNP Bet/NNP Rework/NNP)
#   CrapsPlayer/NNP
#   Class/NNP
#   Stub/NNP
#   (ORGANIZATION CrapsGameState/NNP)
#   Class/NNP
#   CrapsGamePointOff/NNP
#   Class/NNP
#   CrapsGamePointOn/NNP
#   Class/NNP
#   CrapsGame/NNP
#   Design/NNP
#   (PERSON Craps/NNP Game/NNP Deliverables/NNP Optional/NNP)
#   Working/NNP
#   Bets/NNP
#   CrapsPlayer/NNP
#   Class/NNP
#   Craps/NNP
#   Player/NNP
#   Analysis/NNP
#   CrapsPlayer/NNP
#   Design/NNP
#   (ORGANIZATION
#     CrapsPlayerPass/NNP
#     Subclass/NNP
#     Craps/NNP
#     Martingale/NNP
#     Subclass/NNP
#     Craps/NNP
#     Player/NNP
#     Deliverables/NNP)
#   Design/NNP
#   Cleanup/NNP
#   and/CC
#   Refactoring/NNP
#   Design/NNP
#   Review/NNP
#   RandomEventFactory/NNP
#   Design/NNP
#   Wheel/NNP
#   Class/NNP
#   Design/NNP
#   Dice/NNP
#   Class/NNP
#   Design/NNP
#   Table/NNP
#   Class/NNP
#   Design/NNP
#   Player/NNP
#   Class/NNP
#   Design/NNP
#   Game/NNP
#   Class/NNP
#   Design/NNP
#   RouletteGame/NNP
#   Class/NNP
#   Design/NNP
#   CrapsGame/NNP
#   Class/NNP
#   Design/NNP
#   Refactoring/NNP
#   Deliverables/NNP
#   Simple/NNP
#   (PERSON
#     Craps/NNP
#     Players/NNP
#     Simple/NNP
#     Craps/NNP
#     Players/NNP
#     Analysis/NNP)
#   CrapsPlayer/NNP
#   Design/NNP
#   CrapsSimplePlayer/NNP
#   superclass/NN
#   (PERSON Craps/NNP Martingale/NNP Player/NNP Player1326/NNP)
#   State/NNP
#   (PERSON Craps1326/NNP Player/NNP)
#   CrapsCancellation/NNP
#   Player/NNP
#   Simple/NNP
#   (PERSON Craps/NNP Players/NNP Deliverables/NNP)
#   Roll-Counting/NNP
#   Player/NNP
#   Class/NNP
#   Roll-Counting/NNP
#   Analysis/NNP
#   BettingStrategy/NNP
#   Design/NNP
#   NoChangeBetting/NNP
#   Class/NNP
#   MartingaleBetting/NNP
#   Class/NNP
#   Bet1326Betting/NNP
#   Class/NNP
#   CrapsOneBetPlayer/NNP
#   class/NN
#   (ORGANIZATION CrapsTwoBetPlayer/NNP)
#   class/NN
#   (ORGANIZATION CrapsSevenCountPlayer/NNP)
#   class/NN
#   Roll-Counting/NNP
#   Deliverables/NNP
#   Conclusion/NNP
#   Blackjack/NNP
#   This/DT
#   part/NN
#   describes/VBZ
#   the/DT
#   more/RBR
#   complex/JJ
#   game/NN
#   of/IN
#   (ORGANIZATION Blackjack/NNP))
# (S
#   Both/DT
#   the/DT
#   player/NN
#   and/CC
#   the/DT
#   dealer/NN
#   are/VBP
#   trying/VBG
#   to/TO
#   build/VB
#   a/DT
#   hand/NN
#   that/WDT
#   totals/VBZ
#   21/CD
#   points/NNS
#   without/IN
#   going/VBG
#   over/IN)
# (S The/DT hand/NN closest/NN to/TO 21/CD wins/NNS)
# (S
#   This/DT
#   game/NN
#   has/VBZ
#   a/DT
#   number/NN
#   of/IN
#   states/NNS
#   and/CC
#   a/DT
#   number/NN
#   of/IN
#   complex/JJ
#   state-change/NN
#   rules/NNS)
# (S
#   It/PRP
#   has/VBZ
#   very/RB
#   few/JJ
#   different/JJ
#   kinds/NNS
#   of/IN
#   bets/NNS
#   but/CC
#   moderately/RB
#   complex/JJ
#   rules/NNS
#   for/IN
#   game/NN
#   play/NN)
# (S
#   However/RB
#   it/PRP
#   does/VBZ
#   have/VB
#   the/DT
#   most/RBS
#   sophisticated/JJ
#   playing/NN
#   strategy/NN
#   since/IN
#   the/DT
#   player/NN
#   has/VBZ
#   a/DT
#   number/NN
#   of/IN
#   choices/NNS
#   to/TO
#   make/VB)
# (S
#   The/DT
#   chapters/NNS
#   of/IN
#   this/DT
#   part/NN
#   presents/VBZ
#   the/DT
#   details/NNS
#   on/IN
#   the/DT
#   game/NN
#   an/DT
#   overview/NN
#   of/IN
#   the/DT
#   solution/NN
#   and/CC
#   a/DT
#   series/NN
#   of/IN
#   six/CD
#   relatively/RB
#   complex/JJ
#   exercises/NNS
#   to/TO
#   build/VB
#   a/DT
#   complete/JJ
#   simulation/NN
#   of/IN
#   the/DT
#   game/NN)
# (S
#   In/IN
#   the/DT
#   case/NN
#   of/IN
#   Blackjack/NNP
#   we/PRP
#   have/VBP
#   to/TO
#   create/VB
#   a/DT
#   design/NN
#   that/WDT
#   allows/VBZ
#   for/IN
#   considerable/JJ
#   variation/NN
#   in/IN
#   the/DT
#   rules/NNS
#   of/IN
#   the/DT
#   game/NN
#   as/RB
#   well/RB
#   as/IN
#   variation/NN
#   in/IN
#   the/DT
#   player/NN
#   ’/NNP
#   s/NN
#   betting/NN
#   strategies/NNS)
# (S
#   (PERSON Blackjack/NNP)
#   (PERSON Details/NNP Blackjack/NNP)
#   Game/NNP
#   Available/NNP
#   Bets/NNP
#   and/CC
#   (ORGANIZATION
#     Choices/NNPS
#     Betting/NNP
#     Strategies/NNP
#     Blackjack/NNP
#     Solution/NNP
#     Overview/NNP)
#   Preliminary/NNP
#   Survey/NNP
#   of/IN
#   (PERSON Classes/NNP)
#   Preliminary/NNP
#   Class/NNP
#   Structure/NNP
#   A/NNP
#   Walkthrough/NNP
#   Blackjack/NNP
#   Solution/NNP
#   Questions/NNP
#   and/CC
#   (ORGANIZATION Answers/NNP Card/NNP Deck/NNP)
#   and/CC
#   (PERSON Shoe/NNP Classes/NNP Card/NNP Deck/NNP)
#   and/CC
#   (PERSON Shoe/NNP Analysis/NNP)
#   Card-Deck-Shoe/NNP
#   Questions/NNP
#   and/CC
#   (ORGANIZATION Answers/NNP Card/NNP Superclass/NNP)
#   (ORGANIZATION FaceCard/NNP)
#   Class/NNP
#   (ORGANIZATION AceCard/NNP)
#   Class/NNP
#   (PERSON Card/NNP Factory/NNP Function/NNP)
#   Deck/NNP
#   class/NN
#   Shoe/NNP
#   class/NN
#   Card-Deck-Shoe/NNP
#   Deliverables/NNP
#   Hand/NNP
#   and/CC
#   (PERSON
#     Outcome/NNP
#     Classes/NNP
#     Hand/NNP
#     Analysis/NNP
#     Hand/NNP
#     Total/NNP)
#   Class/NNP
#   Design/NNP
#   Hand/NNP
#   (PERSON Hard/NNP Total/NNP)
#   Class/NNP
#   Design/NNP
#   Hand/NNP
#   Soft/NNP
#   Total/NNP
#   Class/NNP
#   Design/NNP
#   (PERSON Card/NNP Class/NNP Updates/NNP Hand/NNP)
#   Class/NNP
#   Design/NNP
#   Hand/NNP
#   Deliverables/NNP
#   Blackjack/NNP
#   Table/NNP
#   Class/NNP
#   Blackjack/NNP
#   Table/NNP
#   Analysis/NNP
#   (ORGANIZATION BlackjackTable/NNP)
#   Class/NNP
#   Hand/NNP
#   (PERSON
#     Rework/NNP
#     Blackjack/NNP
#     Table/NNP
#     Deliverables/NNP
#     Blackjack/NNP)
#   Game/NNP
#   Class/NNP
#   Blackjack/NNP
#   Game/NNP
#   Analysis/NNP
#   Blackjack/NNP
#   Collaboration/NNP
#   (PERSON Dealer/NNP Rules/NNP)
#   (ORGANIZATION BlackjackPlayer/NNP)
#   Class/NNP
#   (PERSON Card/NNP Rework/NNP Hand/NNP Rework/NNP)
#   BlackjackGame/NNP
#   Class/NNP
#   Blackjack/NNP
#   Game/NNP
#   Deliverables/NNP
#   Simple/NNP
#   Blackjack/NNP
#   Player/NNP
#   Class/NNP
#   Blackjack/NNP
#   Player/NNP
#   Analysis/NNP
#   SimpleBlackjackPlayer/NNP
#   Design/NNP
#   Blackjack/NNP
#   Player/NNP
#   Deliverables/NNP
#   Variant/NNP
#   Game/NNP
#   (PERSON Rules/NNP Variant/NNP)
#   Game/NNP
#   Analysis/NNP
#   BlackjackGame/NNP
#   (PERSON Rework/NNP OneDeckGame/NNP)
#   Class/NNP
#   Variant/NNP
#   Game/NNP
#   Deliverables/NNP
#   Conclusion/NNP
#   Fit/NNP
#   and/CC
#   (PERSON Finish/NNP)
#   A/NNP
#   finished/JJ
#   application/NN
#   includes/VBZ
#   more/JJR
#   than/IN
#   just/RB
#   a/DT
#   working/JJ
#   program/NN)
# (S There/EX are/VBP two/CD additional/JJ questions/NNS)
# (S How/WRB do/VB you/PRP know/VB it/PRP works/VBZ)
# (S
#   That/DT
#   is/VBZ
#   do/VBP
#   you/PRP
#   have/VB
#   any/DT
#   tests/NNS
#   that/WDT
#   demonstrate/VBP
#   that/IN
#   it/PRP
#   works/VBZ
#   correctly/RB)
# (S We/PRP address/VBP this/DT by/IN creating/VBG unit/NN tests/NNS)
# (S How/WRB is/VBZ it/PRP designed/VBD)
# (S
#   We/PRP
#   address/VBP
#   this/DT
#   by/IN
#   creating/VBG
#   documentation/NN
#   within/IN
#   the/DT
#   program/NN
#   ’/NNP
#   s/VBZ
#   source/NN
#   files/NNS)
# (S
#   This/DT
#   documentation/NN
#   can/MD
#   be/VB
#   extracted/VBN
#   to/TO
#   create/VB
#   a/DT
#   tidy/JJ
#   complete/JJ
#   reference/NN
#   for/IN
#   all/PDT
#   the/DT
#   classes/NNS
#   and/CC
#   functions/NNS
#   within/IN
#   our/PRP$
#   application/NN)
# (S
#   (PERSON Python/NNP)
#   (ORGANIZATION Unit/NNP)
#   Testing/NNP
#   Using/NNP
#   (PERSON Unit/NNP Tests/NNP)
#   Dependencies/NNP
#   Example/NNP
#   (PERSON Unit/NNP Test/NNP Example/NNP)
#   Class/NNP
#   Definition/NNP
#   Python/NNP
#   doctest/JJS
#   Testing/VBG
#   Building/VBG
#   (PERSON Doctest/NNP Examples/NNP Mixed/NNP)
#   unittest/JJS
#   and/CC
#   doctest/JJS
#   (PERSON Python/NNP Documentation/NNP)
#   Documentation/NNP
#   Development/NNP
#   Using/NNP
#   (PERSON Sphinx/NNP Using/NNP Epydoc/NNP Basic/NNP)
#   RST/NNP
#   (PERSON Markup/NNP Interpreted/NNP Text/NNP)
#   or/CC
#   (PERSON Inline/NNP Markup/NNP)
#   RST/NNP
#   Field/NNP
#   (PERSON Markup/NNP Directives/NNP Standard/NNP Paragraphs/NNP)
#   Class/NNP
#   Example/NNP
#   Example/NNP
#   (PERSON
#     Sphinx/NNP
#     Automodule/NNP
#     Back/NNP
#     Matter/NNP
#     Bibliography/NNP
#     Use/NNP
#     Cases/NNP
#     Computer/NNP
#     Science/NNP)
#   Design/NNP
#   Patterns/NNP
#   Statistics/NNPS
#   (PERSON Python/NNP Casino/NNP)
#   Games/NNP
#   Toolset/NNP
#   Indices/NNP
#   and/CC
#   tables/NNS
#   (PERSON Index/NNP Search/NNP Page/NNP)
#   ©/VBD
#   Copyright/NNP
#   2015/CD
#   (PERSON Steven/NNP F./NNP Lott/NNP))
# (S
#   Created/VBN
#   using/VBG
#   Sphinx/NNP
#   1.3.1./CD
#   index/NN
#   modules/NNS
#   next/IN
#   previous/JJ
#   Building/NNP
#   Skills/NNP
#   in/IN
#   Object-Oriented/NNP
#   Design/NNP
#   3.1/CD
#   documentation/NN
#   »/FW
#   Preface/NNP
#   Why/WRB
#   Read/VB
#   This/DT
#   Book/NNP)
# (S
#   One/CD
#   way/NN
#   to/TO
#   master/VB
#   OO/NNP
#   design/NN
#   is/VBZ
#   do/JJ
#   design/NN
#   and/CC
#   implementation/NN
#   of/IN
#   a/DT
#   large/JJ
#   number/NN
#   of/IN
#   classes/NNS)
# (S
#   This/DT
#   book/NN
#   guides/VBZ
#   you/PRP
#   through/IN
#   exercises/NNS
#   to/TO
#   design/VB
#   dozens/NNS
#   of/IN
#   classes/NNS
#   that/WDT
#   must/MD
#   work/VB
#   together/RB
#   to/TO
#   create/VB
#   a/DT
#   large/JJ
#   –/NN
#   and/CC
#   reasonably/RB
#   complete/JJ
#   –/NNP
#   application/NN)
# (S
#   We/PRP
#   ’/VBP
#   ll/JJ
#   discuss/IN
#   the/DT
#   design/NN
#   in/IN
#   some/DT
#   detail/NN
#   to/TO
#   reveal/VB
#   an/DT
#   approach/NN
#   to/TO
#   object-oriented/JJ
#   design/NN)
# (S
#   While/IN
#   it/PRP
#   is/VBZ
#   also/RB
#   important/JJ
#   to/TO
#   read/VB
#   examples/NNS
#   of/IN
#   good/JJ
#   design/NN
#   a/DT
#   finished/JJ
#   product/NN
#   doesn/NN
#   ’/NNP
#   t/NN
#   reveal/VBD
#   the/DT
#   designer/NN
#   ’/JJ
#   s/JJ
#   decision-making/NN
#   process/NN)
# (S
#   Our/PRP$
#   goal/NN
#   in/IN
#   this/DT
#   book/NN
#   is/VBZ
#   to/TO
#   help/VB
#   programmer/VB
#   understand/VB
#   the/DT
#   design/NN
#   process/NN
#   that/WDT
#   leads/VBZ
#   to/TO
#   a/DT
#   final/JJ
#   product/NN)
# (S
#   Everything/NN
#   is/VBZ
#   Design/NNP
#   It/PRP
#   ’/NNP
#   s/VBD
#   important/JJ
#   to/TO
#   note/VB
#   that/IN
#   all/DT
#   software/NN
#   development/NN
#   involves/VBZ
#   considerable/JJ
#   skill/NN
#   in/IN
#   design/NN)
# (S
#   In/IN
#   some/DT
#   circles/NNS
#   there/EX
#   is/VBZ
#   an/DT
#   attempt/NN
#   to/TO
#   distinguish/VB
#   between/IN
#   architects/NNS
#   or/CC
#   designers/NNS
#   and/CC
#   coders/NNS)
# (S
#   The/DT
#   idea/NN
#   is/VBZ
#   that/IN
#   someone/NN
#   can/MD
#   be/VB
#   able/JJ
#   to/TO
#   work/VB
#   with/IN
#   a/DT
#   language/NN
#   –/NN
#   coding/VBG
#   –/NNS
#   but/CC
#   not/RB
#   quite/RB
#   ready/JJ
#   to/TO
#   do/VB
#   design/NN
#   work/NN)
# (S
#   The/DT
#   coders/NNS
#   can/MD
#   be/VB
#   given/VBN
#   a/DT
#   detailed/JJ
#   “/NN
#   specification/NN
#   ”/NN
#   from/IN
#   which/WDT
#   they/PRP
#   can/MD
#   write/VB
#   code/NN)
# (S
#   This/DT
#   distinction/NN
#   between/IN
#   designers/NNS
#   and/CC
#   coders/NNS
#   doesn/VBP
#   ’/JJ
#   t/NNS
#   really/RB
#   exist/VBP)
# (S
#   It/PRP
#   ’/VBZ
#   s/JJ
#   unhelpful/JJ
#   to/TO
#   try/VB
#   and/CC
#   make/VB
#   this/DT
#   distinction/NN)
# (S
#   All/DT
#   programming/VBG
#   involves/NNS
#   design/NN
#   at/IN
#   some/DT
#   level/NN)
# (S
#   If/IN
#   we/PRP
#   attempt/VBP
#   to/TO
#   write/VB
#   a/DT
#   design/NN
#   specification/NN
#   so/RB
#   detailed/VBD
#   that/IN
#   someone/NN
#   else/RB
#   can/MD
#   transform/VB
#   it/PRP
#   into/IN
#   code/NN
#   without/IN
#   them/PRP
#   having/VBG
#   to/TO
#   make/VB
#   any/DT
#   design/NN
#   decisions/NNS
#   the/DT
#   specification/NN
#   is/VBZ
#   isomorphic/JJ
#   to/TO
#   code/VB
#   but/CC
#   written/VBN
#   in/IN
#   some/DT
#   non-technical/JJ
#   language/NN
#   like/IN
#   (GPE English/NNP))
# (S The/DT design/NN has/VBZ all/PDT the/DT details/NNS of/IN code/NN)
# (S
#   An/DT
#   automated/JJ
#   translation/NN
#   could/MD
#   produce/VB
#   code/NN
#   from/IN
#   this/DT
#   magically/RB
#   complete/JJ
#   with/IN
#   fewer/JJR
#   errors/NNS
#   than/IN
#   a/DT
#   person/NN)
# (S
#   If/IN
#   we/PRP
#   write/VBP
#   specifications/NNS
#   at/IN
#   somewhat/RB
#   more/JJR
#   abstract/JJ
#   level/NN
#   we/PRP
#   ’/VBP
#   re/JJ
#   demanding/NN
#   that/IN
#   the/DT
#   “/NNP
#   coder/NN
#   ”/NNP
#   makes/VBZ
#   some/DT
#   design/NN
#   decisions/NNS
#   to/TO
#   move/VB
#   from/IN
#   the/DT
#   abstraction/NN
#   to/TO
#   concrete/VB
#   code/NN)
# (S
#   The/DT
#   more/RBR
#   abstract/JJ
#   the/DT
#   specification/NN
#   the/DT
#   more/JJR
#   design/JJ
#   work/NN
#   must/MD
#   be/VB
#   done/VBN)
# (S The/DT amount/NN of/IN design/NN work/NN is/VBZ non-zero/JJ)
# (S
#   The/DT
#   point/NN
#   of/IN
#   this/DT
#   book/NN
#   is/VBZ
#   to/TO
#   build/VB
#   skills/NNS
#   in/IN
#   object-oriented/JJ
#   design/NN
#   prior/RB
#   to/TO
#   a/DT
#   project/NN
#   with/IN
#   a/DT
#   fixed/JJ
#   budget/NN
#   and/CC
#   a/DT
#   looming/JJ
#   deadline/NN)
# (S
#   What/WP
#   You/PRP
#   ’/VBP
#   ll/RB
#   Do/VBP
#   This/DT
#   book/NN
#   provides/VBZ
#   a/DT
#   sequence/NN
#   of/IN
#   interesting/JJ
#   and/CC
#   moderately/RB
#   complex/JJ
#   exercises/NNS
#   in/IN
#   (GPE OO/NNP)
#   design/NN)
# (S
#   The/DT
#   exercises/NNS
#   are/VBP
#   not/RB
#   hypothetical/JJ
#   but/CC
#   must/MD
#   lead/VB
#   directly/RB
#   to/TO
#   working/VBG
#   programs/NNS)
# (S
#   The/DT
#   applications/NNS
#   we/PRP
#   will/MD
#   build/VB
#   are/VBP
#   a/DT
#   step/NN
#   above/IN
#   trivial/NN
#   and/CC
#   will/MD
#   require/VB
#   some/DT
#   careful/JJ
#   thought/VBN
#   as/IN
#   part/NN
#   of/IN
#   creating/VBG
#   a/DT
#   workable/JJ
#   design/NN)
# (S
#   Further/RB
#   because/IN
#   the/DT
#   applications/NNS
#   are/VBP
#   largely/RB
#   recreational/JJ
#   in/IN
#   nature/NN
#   they/PRP
#   are/VBP
#   interesting/VBG
#   and/CC
#   engaging/VBG)
# (S
#   This/DT
#   book/NN
#   allows/VBZ
#   the/DT
#   reader/NN
#   to/TO
#   explore/VB
#   the/DT
#   processes/NNS
#   and/CC
#   artifacts/NNS
#   of/IN
#   (ORGANIZATION OO/NNP)
#   design/NN
#   before/IN
#   project/NN
#   deadlines/NNS
#   make/VBP
#   good/JJ
#   design/NN
#   seem/VBP
#   impossible/JJ)
# (S The/DT first/JJ part/NN will/MD be/VB quite/RB detailed/JJ)
# (S
#   The/DT
#   third/JJ
#   part/NN
#   will/MD
#   summarize/VB
#   the/DT
#   designs/NNS
#   at/IN
#   a/DT
#   higher/JJR
#   level/NN
#   of/IN
#   abstraction/NN)
# (S
#   (GPE Audience/NNP)
#   Our/PRP$
#   primary/JJ
#   audience/NN
#   includes/VBZ
#   programmers/NNS
#   who/WP
#   are/VBP
#   new/JJ
#   to/TO
#   OO/NNP
#   programming/NN)
# (S
#   Knowledge/NNP
#   of/IN
#   the/DT
#   (GPE Python/NNP)
#   language/NN
#   is/VBZ
#   essential/JJ)
# (S
#   Since/IN
#   the/DT
#   focus/NN
#   is/VBZ
#   on/IN
#   OO/NNP
#   techniques/NNS
#   some/DT
#   exposure/NN
#   to/TO
#   class/NN
#   definitions/NNS
#   is/VBZ
#   important/JJ)
# (S
#   We/PRP
#   will/MD
#   provide/VB
#   exercises/NNS
#   that/WDT
#   have/VBP
#   four/CD
#   key/JJ
#   features/NNS
#   complex/JJ
#   enough/RB
#   to/TO
#   require/VB
#   careful/JJ
#   design/NN
#   work/NN
#   fun/RB
#   enough/RB
#   to/TO
#   be/VB
#   engaging/VBG
#   easy/JJ
#   enough/RB
#   that/IN
#   results/NNS
#   are/VBP
#   available/JJ
#   immediately/RB
#   and/CC
#   can/MD
#   be/VB
#   built/VBN
#   in/IN
#   simple/JJ
#   stages/NNS)
# (S
#   We/PRP
#   ’/VBP
#   ll/JJ
#   provide/VBP
#   a/DT
#   few/JJ
#   additional/JJ
#   details/NNS
#   on/IN
#   language/NN
#   features/NNS)
# (S
#   We/PRP
#   ’/VBP
#   ll/JJ
#   mark/NN
#   these/DT
#   as/IN
#   “/NNS
#   (PERSON Tips/NNP)
#   ”/NN)
# (S
#   For/IN
#   more/RBR
#   advanced/JJ
#   students/NNS
#   these/DT
#   tips/NNS
#   will/MD
#   be/VB
#   review/VBN
#   material/NN)
# (S
#   We/PRP
#   will/MD
#   not/RB
#   provide/VB
#   a/DT
#   thorough/JJ
#   background/NN
#   in/IN
#   any/DT
#   programming/JJ
#   language/NN)
# (S
#   The/DT
#   student/NN
#   is/VBZ
#   expected/VBN
#   to/TO
#   know/VB
#   the/DT
#   basics/NNS
#   of/IN
#   the/DT
#   language/NN
#   and/CC
#   tools/NNS)
# (S
#   (GPE Helpful/NNP)
#   additional/JJ
#   skills/NNS
#   include/VBP
#   using/VBG
#   one/CD
#   of/IN
#   the/DT
#   various/JJ
#   unit/NN
#   test/NN
#   and/CC
#   documentation/NN
#   frameworks/NNS
#   available/JJ)
# (S
#   We/PRP
#   ’/VBP
#   ve/RB
#   included/VBN
#   information/NN
#   in/IN
#   the/DT
#   appendices/NNS)
# (S (GPE Classroom/NN) (ORGANIZATION Use/NN))
# (S
#   Instructors/NNS
#   are/VBP
#   always/RB
#   looking/VBG
#   for/IN
#   classroom/NN
#   projects/NNS
#   that/WDT
#   are/VBP
#   engaging/VBG
#   comprehensible/JJ
#   and/CC
#   focus/VB
#   on/IN
#   perfecting/VBG
#   language/NN
#   skills/NNS)
# (S
#   Many/JJ
#   real-world/JJ
#   applications/NNS
#   require/VBP
#   considerable/JJ
#   explanation/NN
#   of/IN
#   the/DT
#   problem/NN
#   domain/VB
#   the/DT
#   time/NN
#   spent/VBN
#   reviewing/VBG
#   background/NN
#   information/NN
#   detracts/NNS
#   from/IN
#   the/DT
#   time/NN
#   available/JJ
#   to/TO
#   do/VB
#   the/DT
#   relevant/NN
#   programming/NN)
# (S
#   While/IN
#   all/DT
#   application/NN
#   programming/VBG
#   requires/VBZ
#   some/DT
#   domain/NN
#   knowledge/VBP
#   the/DT
#   idea/NN
#   behind/IN
#   these/DT
#   exercises/NNS
#   is/VBZ
#   to/TO
#   pick/VB
#   a/DT
#   domain/NN
#   that/IN
#   many/JJ
#   people/NNS
#   know/VBP
#   a/DT
#   little/JJ
#   bit/NN
#   about/IN)
# (S
#   This/DT
#   allows/VBZ
#   an/DT
#   instructor/NN
#   to/TO
#   use/VB
#   some/DT
#   or/CC
#   all/DT
#   of/IN
#   these/DT
#   exercises/NNS
#   without/IN
#   wasting/VBG
#   precious/JJ
#   classroom/NN
#   time/NN
#   on/IN
#   incidental/JJ
#   details/NNS
#   required/VBN
#   to/TO
#   understand/VB
#   the/DT
#   problem/NN)
# (S Skills/NNS)
# (S
#   This/DT
#   book/NN
#   assumes/VBZ
#   an/DT
#   introductory/JJ
#   level/NN
#   of/IN
#   skill/NN
#   in/IN
#   the/DT
#   (GPE Python/NNP)
#   language/NN)
# (S
#   We/PRP
#   ’/VBP
#   ll/JJ
#   focus/NN
#   on/IN
#   Python/NNP
#   3.4/CD
#   as/IN
#   a/DT
#   minimum/NN
#   with/IN
#   references/NNS
#   to/TO
#   features/NNS
#   of/IN
#   Python/NNP
#   3.5/CD
#   Student/NNP
#   skills/NNS
#   we/PRP
#   expect/VBP
#   include/VBP
#   the/DT
#   following/JJ)
# (S
#   If/IN
#   you/PRP
#   can/MD
#   ’/VB
#   t/VB
#   do/VB
#   these/DT
#   things/NNS
#   this/DT
#   book/NN
#   may/MD
#   be/VB
#   too/RB
#   advanced/JJ)
# (S
#   (GPE Create/NNP)
#   source/NN
#   files/NNS
#   compile/NN
#   and/CC
#   run/VB
#   application/NN
#   programs/NNS)
# (S
#   While/IN
#   this/DT
#   may/MD
#   seem/VB
#   obvious/JJ
#   we/PRP
#   don/VBP
#   ’/JJ
#   t/NN
#   discuss/VBZ
#   any/DT
#   integrated/JJ
#   development/NN
#   environment/NN
#   (ORGANIZATION IDE/NNP))
# (S
#   We/PRP
#   have/VBP
#   to/TO
#   assume/VB
#   these/DT
#   basic/JJ
#   skills/NNS
#   are/VBP
#   present/JJ)
# (S
#   Use/NNP
#   of/IN
#   the/DT
#   core/NN
#   procedural/JJ
#   programming/NN
#   constructs/NNS
#   variables/VBZ
#   statements/NNS
#   exceptions/NNS
#   functions/NNS)
# (S
#   We/PRP
#   will/MD
#   not/RB
#   for/IN
#   example/NN
#   spend/VBP
#   any/DT
#   time/NN
#   on/IN
#   design/NN
#   of/IN
#   loops/NNS
#   that/WDT
#   terminate/VBP
#   properly/RB)
# (S
#   Some/DT
#   exposure/NN
#   to/TO
#   class/NN
#   definitions/NNS
#   and/CC
#   subclasses/NNS)
# (S
#   This/DT
#   includes/VBZ
#   managing/VBG
#   the/DT
#   basic/JJ
#   features/NNS
#   of/IN
#   inheritance/NN
#   as/RB
#   well/RB
#   as/IN
#   overloaded/VBN
#   method/NN
#   names/NNS)
# (S
#   Some/DT
#   exposure/NN
#   to/TO
#   the/DT
#   various/JJ
#   kinds/NNS
#   of/IN
#   built-in/JJ
#   collections/NNS)
# (S
#   Optionally/RB
#   some/DT
#   experience/NN
#   with/IN
#   a/DT
#   unit/NN
#   testing/VBG
#   framework/NN)
# (S
#   See/VB
#   the/DT
#   appendices/NNS
#   for/IN
#   supplemental/JJ
#   exercises/NNS
#   if/IN
#   you/PRP
#   aren/VBP
#   ’/JJ
#   t/NN
#   familiar/JJ
#   with/IN
#   (PERSON Python/NNP)
#   ’/NNP
#   s/VBZ
#   unittest/JJS
#   or/CC
#   doctest/VB)
# (S
#   Optionally/RB
#   some/DT
#   experience/NN
#   writing/VBG
#   formal/JJ
#   documentation/NN)
# (S
#   For/IN
#   (GPE Python/NNP)
#   programmers/NNS
#   this/DT
#   means/VBZ
#   writing/JJ
#   docstrings/NNS
#   and/CC
#   using/VBG
#   a/DT
#   tool/NN
#   like/IN
#   (PERSON Epydoc/NNP)
#   or/CC
#   sphinx/VB)
# (S
#   See/VB
#   the/DT
#   appendices/NNS
#   for/IN
#   supplemental/JJ
#   exerises/NNS
#   if/IN
#   you/PRP
#   aren/VBP
#   ’/JJ
#   t/NN
#   familiar/JJ
#   with/IN
#   formal/JJ
#   deliverable/JJ
#   documentation/NN)
# (S
#   (ORGANIZATION Organization/NN)
#   of/IN
#   This/DT
#   Book/NNP
#   This/DT
#   book/NN
#   presents/VBZ
#   a/DT
#   series/NN
#   of/IN
#   exercises/NNS
#   to/TO
#   build/VB
#   simulations/NNS
#   of/IN
#   the/DT
#   common/JJ
#   popular/JJ
#   casino/NN
#   table/JJ
#   games/NNS
#   (PERSON Roulette/NNP Craps/NNP)
#   and/CC
#   (ORGANIZATION Blackjack/NNP))
# (S
#   Each/DT
#   simulation/NN
#   can/MD
#   be/VB
#   extended/VBN
#   to/TO
#   include/VB
#   variations/NNS
#   on/IN
#   the/DT
#   player/NN
#   ’/NNP
#   s/NN
#   betting/NN
#   system/NN)
# (S
#   With/IN
#   a/DT
#   simple/JJ
#   statistical/JJ
#   approach/NN
#   we/PRP
#   can/MD
#   show/VB
#   the/DT
#   realistic/JJ
#   expectations/NNS
#   for/IN
#   any/DT
#   betting/NN
#   system/NN)
# (S
#   Each/DT
#   of/IN
#   these/DT
#   games/NNS
#   has/VBZ
#   a/DT
#   separate/JJ
#   part/NN
#   in/IN
#   this/DT
#   book/NN)
# (S
#   Each/DT
#   part/NN
#   consists/VBZ
#   of/IN
#   a/DT
#   number/NN
#   of/IN
#   individual/JJ
#   exercises/NNS
#   to/TO
#   build/VB
#   the/DT
#   entire/JJ
#   simulation/NN)
# (S
#   The/DT
#   completed/VBN
#   project/NN
#   results/NNS
#   in/IN
#   an/DT
#   application/NN
#   that/WDT
#   can/MD
#   provide/VB
#   simple/JJ
#   tabular/JJ
#   results/NNS
#   that/WDT
#   shows/VBZ
#   the/DT
#   average/JJ
#   losses/NNS
#   expected/VBN
#   from/IN
#   each/DT
#   betting/VBG
#   strategy/NN)
# (S
#   The/DT
#   interesting/JJ
#   degree/NN
#   of/IN
#   freedom/NN
#   in/IN
#   each/DT
#   of/IN
#   the/DT
#   simulations/NNS
#   is/VBZ
#   the/DT
#   player/NN
#   ’/NNP
#   s/NN
#   betting/VBG
#   strategy/NN)
# (S
#   The/DT
#   design/NN
#   will/MD
#   permit/VB
#   easy/JJ
#   adaptation/NN
#   and/CC
#   maintenance/NN
#   of/IN
#   the/DT
#   player/NN
#   ’/NNP
#   s/NN
#   strategies/NNS)
# (S
#   The/DT
#   resulting/JJ
#   application/NN
#   program/NN
#   can/MD
#   be/VB
#   extended/VBN
#   by/IN
#   inserting/VBG
#   additional/JJ
#   betting/NN
#   systems/NNS
#   which/WDT
#   allows/VBZ
#   exploration/NN
#   of/IN
#   what/WP
#   if/IN
#   any/DT
#   player/NN
#   actions/NNS
#   can/MD
#   minimize/VB
#   the/DT
#   losses/NNS)
# (S (GPE Roulette/NN))
# (S
#   For/IN
#   those/DT
#   who/WP
#   ’/VBP
#   ve/NNS
#   never/RB
#   been/VBN
#   in/IN
#   a/DT
#   casino/NN
#   or/CC
#   seen/VBN
#   movies/NNS
#   that/WDT
#   have/VBP
#   casinos/VBN
#   in/IN
#   them/PRP
#   (PERSON Roulette/NNP)
#   is/VBZ
#   the/DT
#   game/NN
#   with/IN
#   the/DT
#   big/JJ
#   wheel/NN)
# (S
#   They/PRP
#   spin/VBP
#   the/DT
#   wheel/NN
#   and/CC
#   toss/NN
#   in/IN
#   a/DT
#   marble/NN)
# (S
#   When/WRB
#   the/DT
#   wheel/NN
#   stops/VBZ
#   spinning/VBG
#   the/DT
#   bin/NN
#   in/IN
#   which/WDT
#   the/DT
#   marble/NN
#   rests/VBZ
#   defines/VBZ
#   the/DT
#   winning/NN
#   outcomes/NNS)
# (S
#   People/NNS
#   who/WP
#   bet/VBP
#   on/IN
#   the/DT
#   right/JJ
#   things/NNS
#   get/VBP
#   money/NN)
# (S
#   People/NNS
#   who/WP
#   bet/VBP
#   on/IN
#   the/DT
#   wrong/JJ
#   things/NNS
#   lose/VBP
#   money/NN)
# (S
#   Starting/VBG
#   in/IN
#   Roulette/NNP
#   we/PRP
#   proceed/VBP
#   slowly/RB
#   building/VBG
#   up/RP
#   the/DT
#   necessary/JJ
#   application/NN
#   one/CD
#   class/NN
#   at/IN
#   a/DT
#   time/NN)
# (S
#   Since/IN
#   this/DT
#   is/VBZ
#   the/DT
#   simplest/JJ
#   game/NN
#   the/DT
#   individual/JJ
#   classes/NNS
#   reflect/VBP
#   that/IN
#   simplicity/NN)
# (S
#   We/PRP
#   focus/VBP
#   on/IN
#   isolation/NN
#   of/IN
#   responsibilities/NNS
#   creating/VBG
#   a/DT
#   considerable/JJ
#   number/NN
#   of/IN
#   classes/NNS)
# (S
#   The/DT
#   idea/NN
#   is/VBZ
#   to/TO
#   build/VB
#   skills/NNS
#   in/IN
#   object/JJ
#   design/NN
#   by/IN
#   applying/VBG
#   those/DT
#   skills/NNS
#   to/TO
#   a/DT
#   number/NN
#   of/IN
#   classes/NNS)
# (S
#   The/DT
#   first/JJ
#   chapter/NN
#   of/IN
#   the/DT
#   part/NN
#   provides/VBZ
#   details/NNS
#   on/IN
#   the/DT
#   game/NN
#   of/IN
#   (GPE Roulette/NNP)
#   and/CC
#   the/DT
#   problem/NN
#   that/IN
#   the/DT
#   simulation/NN
#   solves/NNS)
# (S
#   The/DT
#   second/JJ
#   chapter/NN
#   is/VBZ
#   an/DT
#   overview/NN
#   of/IN
#   the/DT
#   solution/NN
#   setting/VBG
#   out/RP
#   the/DT
#   highest-level/JJ
#   design/NN
#   for/IN
#   the/DT
#   application/NN
#   software/NN)
# (S
#   This/DT
#   chapter/NN
#   includes/VBZ
#   a/DT
#   technique/NN
#   for/IN
#   doing/VBG
#   a/DT
#   “/JJ
#   walk-through/JJ
#   ”/NN
#   of/IN
#   the/DT
#   design/NN
#   to/TO
#   be/VB
#   confident/JJ
#   that/IN
#   the/DT
#   design/NN
#   will/MD
#   actually/RB
#   solve/VB
#   the/DT
#   problem/NN)
# (S
#   Each/DT
#   of/IN
#   the/DT
#   remaining/VBG
#   sixteen/JJ
#   chapters/NNS
#   is/VBZ
#   a/DT
#   design/NN
#   and/CC
#   programming/NN
#   exercise/NN
#   to/TO
#   be/VB
#   completed/VBN
#   by/IN
#   the/DT
#   student/NN)
# (S
#   Plus/CC
#   or/CC
#   minus/CC
#   a/DT
#   Frequently/RB
#   Asked/VBN
#   (PERSON Questions/NNS FAQ/NNP)
#   section/NN
#   each/DT
#   chapter/NN
#   has/VBZ
#   the/DT
#   same/JJ
#   basic/JJ
#   structure/NN
#   an/DT
#   overview/NN
#   of/IN
#   the/DT
#   components/NNS
#   being/VBG
#   designed/VBN
#   some/DT
#   design/NN
#   details/NNS
#   and/CC
#   a/DT
#   summary/NN
#   of/IN
#   the/DT
#   deliverables/NNS
#   to/TO
#   be/VB
#   built/VBN)
# (S
#   The/DT
#   overview/NN
#   section/NN
#   presents/VBZ
#   some/DT
#   justification/NN
#   and/CC
#   rationale/NN
#   for/IN
#   the/DT
#   design/NN)
# (S
#   This/DT
#   material/NN
#   should/MD
#   help/VB
#   the/DT
#   student/NN
#   understand/NN
#   why/WRB
#   the/DT
#   particular/JJ
#   design/NN
#   was/VBD
#   chosen/VBN)
# (S
#   The/DT
#   design/NN
#   section/NN
#   provides/VBZ
#   a/DT
#   more/RBR
#   detailed/JJ
#   specification/NN
#   of/IN
#   the/DT
#   class/NN
#   or/CC
#   classes/NNS
#   to/TO
#   be/VB
#   built/VBN)
# (S
#   This/DT
#   will/MD
#   include/VB
#   some/DT
#   technical/JJ
#   information/NN
#   on/IN
#   Java/NNP
#   or/CC
#   (GPE Python/NNP)
#   implementation/NN
#   techniques/NNS)
# (S Craps/NNS)
# (S
#   For/IN
#   those/DT
#   who/WP
#   ’/VBP
#   ve/NNS
#   never/RB
#   been/VBN
#   in/IN
#   a/DT
#   casino/NN
#   or/CC
#   seen/VBN
#   the/DT
#   play/NN
#   “/NNP
#   Guys/NNP
#   and/CC
#   (PERSON Dolls/NNP)
#   ”/NNP
#   Craps/NNP
#   is/VBZ
#   the/DT
#   game/NN
#   with/IN
#   the/DT
#   dice/NNS)
# (S A/DT player/NN rolls/VBZ “/JJ shoots/NNS ”/VBP the/DT dice/NN)
# (S
#   Sometimes/RB
#   there/EX
#   ’/JJ
#   s/NN
#   a/DT
#   great/JJ
#   deal/NN
#   of/IN
#   shouting/VBG
#   and/CC
#   clapping/VBG)
# (S
#   A/DT
#   throw/NN
#   of/IN
#   the/DT
#   dice/NN
#   may/MD
#   –/VB
#   or/CC
#   may/MD
#   not/RB
#   –/VB
#   resolve/NNS
#   bets/NNS)
# (S
#   Additionally/RB
#   a/DT
#   throw/NN
#   of/IN
#   the/DT
#   dice/NN
#   may/MD
#   also/RB
#   change/VB
#   the/DT
#   state/NN
#   of/IN
#   the/DT
#   game/NN)
# (S
#   A/DT
#   casino/NN
#   provides/VBZ
#   a/DT
#   number/NN
#   of/IN
#   visual/JJ
#   cues/NNS
#   as/IN
#   to/TO
#   the/DT
#   state/NN
#   of/IN
#   the/DT
#   game/NN
#   and/CC
#   the/DT
#   various/JJ
#   bets/NNS)
# (S
#   In/IN
#   Craps/NNP
#   we/PRP
#   build/VBP
#   on/IN
#   the/DT
#   design/NN
#   patterns/VBZ
#   from/IN
#   (GPE Roulette/NNP))
# (S
#   (PERSON Craps/NNP)
#   however/RB
#   is/VBZ
#   a/DT
#   stateful/JJ
#   game/NN
#   so/RB
#   there/EX
#   is/VBZ
#   a/DT
#   more/RBR
#   sophisticated/JJ
#   design/NN
#   to/TO
#   handle/VB
#   the/DT
#   interactions/NNS
#   between/IN
#   dice/JJ
#   game/NN
#   state/NN
#   and/CC
#   player/NN)
# (S
#   We/PRP
#   exploit/VBP
#   the/DT
#   State/NNP
#   design/NN
#   pattern/NN
#   to/TO
#   show/VB
#   how/WRB
#   the/DT
#   design/NN
#   pattern/NN
#   can/MD
#   be/VB
#   applied/VBN
#   to/TO
#   this/DT
#   simple/JJ
#   situation/NN)
# (S
#   The/DT
#   first/JJ
#   chapter/NN
#   is/VBZ
#   background/VBN
#   information/NN
#   on/IN
#   the/DT
#   game/NN
#   of/IN
#   (GPE Craps/NNP)
#   and/CC
#   the/DT
#   problem/NN
#   that/IN
#   the/DT
#   simulation/NN
#   solves/NNS)
# (S
#   The/DT
#   second/JJ
#   chapter/NN
#   is/VBZ
#   an/DT
#   overview/NN
#   of/IN
#   the/DT
#   solution/NN
#   setting/VBG
#   out/RP
#   the/DT
#   highest-level/JJ
#   design/NN
#   for/IN
#   the/DT
#   application/NN
#   software/NN)
# (S
#   This/DT
#   chapter/NN
#   also/RB
#   provides/VBZ
#   a/DT
#   “/JJ
#   walk-through/JJ
#   ”/NN
#   of/IN
#   the/DT
#   design/NN)
# (S
#   Each/DT
#   of/IN
#   the/DT
#   remaining/VBG
#   eleven/JJ
#   chapters/NNS
#   is/VBZ
#   an/DT
#   exercise/NN
#   to/TO
#   be/VB
#   completed/VBN
#   by/IN
#   the/DT
#   student/NN)
# (S
#   Each/DT
#   chapter/NN
#   has/VBZ
#   the/DT
#   same/JJ
#   basic/JJ
#   structure/NN
#   an/DT
#   overview/NN
#   of/IN
#   the/DT
#   component/NN
#   being/VBG
#   designed/VBN
#   some/DT
#   design/NN
#   details/NNS
#   and/CC
#   a/DT
#   summary/NN
#   of/IN
#   the/DT
#   deliverables/NNS
#   to/TO
#   be/VB
#   built/VBN)
# (S (GPE Blackjack/NN))
# (S
#   For/IN
#   those/DT
#   who/WP
#   ’/VBP
#   ve/NNS
#   never/RB
#   been/VBN
#   in/IN
#   a/DT
#   casino/NN
#   or/CC
#   seen/VBN
#   a/DT
#   movie/NN
#   with/IN
#   (PERSON Blackjack/NNP Blackjack/NNP)
#   is/VBZ
#   a/DT
#   game/NN
#   with/IN
#   cards/NNS)
# (S
#   The/DT
#   dealer/NN
#   deals/NNS
#   two/CD
#   cards/NNS
#   to/TO
#   themselves/PRP
#   and/CC
#   each/DT
#   player/NN)
# (S
#   One/CD
#   of/IN
#   the/DT
#   dealer/NN
#   ’/NNP
#   s/NN
#   card/NN
#   is/VBZ
#   up/RB
#   and/CC
#   one/CD
#   is/VBZ
#   down/RB
#   providing/VBG
#   a/DT
#   little/JJ
#   bit/NN
#   of/IN
#   information/NN
#   on/IN
#   the/DT
#   dealer/NN
#   ’/NNP
#   s/NN
#   hand/NN)
# (S
#   The/DT
#   players/NNS
#   may/MD
#   ask/VB
#   for/IN
#   additional/JJ
#   cards/NNS
#   or/CC
#   keep/VB
#   the/DT
#   hand/NN
#   they/PRP
#   ’/VBP
#   ve/NNS
#   got/VBD)
# (S
#   The/DT
#   idea/NN
#   is/VBZ
#   to/TO
#   build/VB
#   a/DT
#   hand/NN
#   that/WDT
#   ’/VBZ
#   s/RB
#   close/JJ
#   to/TO
#   21/CD
#   points/NNS
#   but/CC
#   not/RB
#   more/JJR
#   than/IN
#   21/CD)
# (S
#   In/IN
#   (GPE Craps/NNP)
#   and/CC
#   (PERSON Roulette/NNP)
#   there/EX
#   are/VBP
#   a/DT
#   lot/NN
#   of/IN
#   bets/NNS
#   but/CC
#   few/JJ
#   player/NN
#   decisions/NNS)
# (S
#   In/IN
#   (GPE Blackjack/NNP)
#   there/EX
#   are/VBP
#   few/JJ
#   bets/NNS
#   but/CC
#   really/RB
#   complex/JJ
#   player/NN
#   decisions/NNS)
# (S
#   In/IN
#   Blackjack/NNP
#   the/DT
#   game/NN
#   states/NNS
#   are/VBP
#   more/RBR
#   sophisticated/JJ
#   than/IN
#   (PERSON Craps/NNP)
#   or/CC
#   (PERSON Roulette/NNP))
# (S
#   In/IN
#   casino/NN
#   gift/NN
#   shops/NNS
#   you/PRP
#   can/MD
#   buy/VB
#   small/JJ
#   summary/JJ
#   cards/NNS
#   that/WDT
#   enumerate/VBP
#   all/DT
#   possible/JJ
#   game/NN
#   states/NNS
#   and/CC
#   responses/NNS)
# (S
#   The/DT
#   more/RBR
#   advanced/JJ
#   student/NN
#   can/MD
#   tackle/VB
#   these/DT
#   sophisticated/JJ
#   playing/NN
#   strategies/NNS)
# (S
#   For/IN
#   the/DT
#   less/RBR
#   advanced/JJ
#   student/NN
#   we/PRP
#   will/MD
#   simplify/VB
#   the/DT
#   strategies/NNS
#   down/RP
#   to/TO
#   a/DT
#   few/JJ
#   key/JJ
#   conditions/NNS)
# (S
#   The/DT
#   first/JJ
#   two/CD
#   chapters/NNS
#   are/VBP
#   background/VBN
#   information/NN
#   on/IN
#   the/DT
#   game/NN
#   of/IN
#   Blackjack/NNP
#   the/DT
#   problem/NN
#   that/IN
#   the/DT
#   simulation/NN
#   solves/NNS
#   and/CC
#   an/DT
#   overview/NN
#   of/IN
#   the/DT
#   solution/NN
#   setting/VBG
#   out/RP
#   the/DT
#   highest-level/JJ
#   design/NN
#   for/IN
#   the/DT
#   application/NN
#   software/NN)
# (S
#   Each/DT
#   of/IN
#   the/DT
#   remaining/VBG
#   six/CD
#   chapters/NNS
#   is/VBZ
#   an/DT
#   exercise/NN
#   to/TO
#   be/VB
#   completed/VBN
#   by/IN
#   the/DT
#   student/NN)
# (S
#   Since/IN
#   this/DT
#   is/VBZ
#   more/RBR
#   advanced/JJ
#   material/NN
#   and/CC
#   builds/NNS
#   on/IN
#   previous/JJ
#   work/NN
#   this/DT
#   part/NN
#   has/VBZ
#   many/JJ
#   simple/JJ
#   deliverables/NNS
#   compressed/VBN
#   into/IN
#   the/DT
#   individual/JJ
#   chapters/NNS)
# (S (GPE Fit/NNP) and/CC (GPE Finish/NNP))
# (S
#   We/PRP
#   include/VBP
#   several/JJ
#   fit-and-finish/JJ
#   issues/NNS
#   in/IN
#   (GPE Fit/NNP)
#   and/CC
#   (GPE Finish/NNP))
# (S
#   This/DT
#   includes/VBZ
#   more/JJR
#   information/NN
#   and/CC
#   examples/NNS
#   on/IN
#   unit/NN
#   testing/NN
#   and/CC
#   documentation/NN)
# (S
#   Additionally/RB
#   we/PRP
#   cover/VBP
#   some/DT
#   “/JJ
#   main/JJ
#   program/NN
#   ”/NNS
#   issues/NNS
#   required/VBN
#   to/TO
#   knit/VB
#   all/DT
#   of/IN
#   the/DT
#   software/NN
#   components/VBZ
#   together/RB
#   into/IN
#   a/DT
#   finished/JJ
#   whole/NN)
# (S Why/WRB This/DT Subject/NN)
# (S
#   (GPE Casino/NN)
#   table/JJ
#   games/NNS
#   may/MD
#   seem/VB
#   like/IN
#   an/DT
#   odd/JJ
#   choice/NN
#   of/IN
#   subject/JJ
#   matter/NN
#   for/IN
#   programming/VBG
#   exercises/NNS)
# (S
#   We/PRP
#   find/VBP
#   that/IN
#   casino/NN
#   games/NNS
#   have/VBP
#   a/DT
#   number/NN
#   of/IN
#   advantages/NNS
#   for/IN
#   teaching/VBG
#   OO/NNP
#   design/NN
#   and/CC
#   (ORGANIZATION OO/NNP)
#   programming/NN)
# (S
#   (GPE Casino/NN)
#   games/NNS
#   have/VBP
#   an/DT
#   almost/RB
#   ideal/JJ
#   level/NN
#   of/IN
#   complexity/NN)
# (S
#   If/IN
#   they/PRP
#   were/VBD
#   too/RB
#   simple/JJ
#   the/DT
#   house/NN
#   edge/NN
#   would/MD
#   be/VB
#   too/RB
#   obvious/JJ
#   and/CC
#   people/NNS
#   would/MD
#   not/RB
#   play/VB
#   them/PRP)
# (S
#   If/IN
#   they/PRP
#   were/VBD
#   too/RB
#   complex/JJ
#   people/NNS
#   would/MD
#   not/RB
#   enjoy/VB
#   them/PRP
#   as/IN
#   simple/JJ
#   recreation/NN)
# (S Years/NNS centuries/NNS)
# (S
#   of/IN
#   experience/NN
#   in/IN
#   the/DT
#   gaming/NN
#   industry/NN
#   has/VBZ
#   fine-tuned/VBN
#   the/DT
#   table/NN
#   games/NNS
#   to/TO
#   fit/VB
#   nicely/RB
#   with/IN
#   the/DT
#   limits/NNS
#   of/IN
#   our/PRP$
#   human/JJ
#   intellect/NN)
# (S
#   Simulation/NN
#   of/IN
#   discrete/JJ
#   phenomena/NN
#   lies/VBZ
#   at/IN
#   the/DT
#   origin/NN
#   of/IN
#   OO/NNP
#   programming/VBG)
# (S
#   We/PRP
#   have/VBP
#   found/VBN
#   it/PRP
#   easier/JJR
#   to/TO
#   motivate/VB
#   explain/NN
#   and/CC
#   justify/VB
#   OO/NNP
#   design/NN
#   when/WRB
#   solving/VBG
#   simulation/NN
#   problems/NNS)
# (S
#   The/DT
#   student/NN
#   can/MD
#   then/RB
#   leverage/VB
#   this/DT
#   insight/NN
#   into/IN
#   other/JJ
#   applications/NNS
#   of/IN
#   OO/NNP
#   programming/VBG
#   for/IN
#   more/JJR
#   common/JJ
#   transactional/NN
#   applications/NNS)
# (S
#   The/DT
#   results/NNS
#   are/VBP
#   sophisticated/JJ
#   but/CC
#   easy/JJ
#   to/TO
#   interpret/VB)
# (S
#   (GPE Probability/NNP)
#   theory/NN
#   has/VBZ
#   been/VBN
#   applied/VBN
#   by/IN
#   others/NNS
#   to/TO
#   develop/VB
#   precise/JJ
#   expectations/NNS
#   for/IN
#   each/DT
#   game/NN)
# (S
#   These/DT
#   simulations/NNS
#   should/MD
#   produce/VB
#   results/NNS
#   consistent/JJ
#   with/IN
#   the/DT
#   known/JJ
#   probabilities/NNS)
# (S
#   This/DT
#   book/NN
#   will/MD
#   skim/VB
#   over/IN
#   the/DT
#   probability/NN
#   theory/NN
#   in/IN
#   order/NN
#   to/TO
#   focus/VB
#   on/IN
#   the/DT
#   programming/NN)
# (S
#   For/IN
#   a/DT
#   few/JJ
#   exercises/VBZ
#   the/DT
#   theoretical/JJ
#   results/NNS
#   will/MD
#   be/VB
#   provided/VBN
#   to/TO
#   serve/VB
#   as/IN
#   checks/NNS
#   on/IN
#   the/DT
#   correctness/NN
#   of/IN
#   the/DT
#   student/NN
#   ’/NNP
#   s/NN
#   work/NN)
# (S
#   They/PRP
#   ’/VBP
#   re/VB
#   more/JJR
#   fun/NN
#   than/IN
#   most/JJS
#   other/JJ
#   programming/NN
#   problems/NNS)
# (S This/DT book/NN does/VBZ not/RB endorse/VB casino/NN gaming/NN)
# (S
#   Indeed/RB
#   one/CD
#   of/IN
#   the/DT
#   messages/NNS
#   of/IN
#   this/DT
#   book/NN
#   is/VBZ
#   that/IN
#   all/DT
#   casino/NN
#   games/NNS
#   are/VBP
#   biased/VBN
#   against/IN
#   the/DT
#   player/NN)
# (S
#   Even/RB
#   the/DT
#   most/RBS
#   casual/JJ
#   study/NN
#   of/IN
#   the/DT
#   results/NNS
#   of/IN
#   the/DT
#   exercises/NNS
#   will/MD
#   allow/VB
#   the/DT
#   student/NN
#   to/TO
#   see/VB
#   the/DT
#   magnitude/NN
#   of/IN
#   the/DT
#   house/NN
#   edge/NN
#   in/IN
#   each/DT
#   of/IN
#   the/DT
#   games/NNS
#   presented/VBD)
# (S
#   Conventions/NNS
#   Used/VBN
#   in/IN
#   This/DT
#   Book/NNP
#   Here/RB
#   is/VBZ
#   how/WRB
#   we/PRP
#   might/MD
#   present/VB
#   code/NN)
# (S
#   (PERSON Typical/JJ)
#   (PERSON Python/NNP Example/NNP)
#   from/IN
#   collections/NNS
#   import/VBP
#   defaultdict/JJ
#   combo/NN
#   defaultdict/NN
#   int/NN
#   for/IN
#   i/NN
#   in/IN
#   range/NN
#   1,7/CD
#   for/IN
#   j/NN
#   in/IN
#   range/NN
#   1,7/CD
#   roll=/NN
#   i+j/NN
#   combo/NN
#   roll/NN
#   +=/VBD
#   1/CD
#   for/IN
#   n/NN
#   in/IN
#   range/NN
#   2,13/CD
#   print/NN
#   ``/``
#   0/CD
#   d/NN
#   1/CD
#   .2/NN
#   ''/''
#   .format/CC
#   n/JJ
#   combo/NN
#   n/JJ
#   /36.0/NNP
#   We/PRP
#   create/VBP
#   a/DT
#   (GPE Python/NNP)
#   dictionary/NN
#   a/DT
#   map/NN
#   from/IN
#   key/JJ
#   to/TO
#   value/NN)
# (S
#   We/PRP
#   use/VBP
#   the/DT
#   collections.defaultdict/NN
#   so/IN
#   that/IN
#   missing/VBG
#   keys/NNS
#   are/VBP
#   created/VBN
#   in/IN
#   the/DT
#   dictionary/NN
#   with/IN
#   an/DT
#   initial/JJ
#   value/NN
#   created/VBN
#   by/IN
#   the/DT
#   int/NN
#   function/NN)
# (S
#   We/PRP
#   iterate/VBP
#   through/IN
#   all/DT
#   combinations/NNS
#   of/IN
#   two/CD
#   dice/NNS
#   using/VBG
#   variables/NNS
#   i/NNS
#   and/CC
#   j/NN
#   to/TO
#   represent/VB
#   each/DT
#   die/NN)
# (S We/PRP sum/VBP the/DT dice/NNS to/TO create/VB a/DT roll/NN)
# (S
#   We/PRP
#   increment/VBP
#   the/DT
#   value/NN
#   in/IN
#   the/DT
#   dictionary/NN
#   based/VBN
#   on/IN
#   the/DT
#   roll/NN)
# (S
#   Finally/RB
#   we/PRP
#   print/VBP
#   each/DT
#   member/NN
#   of/IN
#   the/DT
#   resulting/VBG
#   dictionary/JJ)
# (S
#   We/PRP
#   ’/VBP
#   ve/NNS
#   used/VBD
#   a/DT
#   sophisticated/JJ
#   format/NN
#   string/NN
#   that/WDT
#   interpolates/VBZ
#   a/DT
#   decimal/JJ
#   value/NN
#   and/CC
#   a/DT
#   floating-point/JJ
#   percentage/NN
#   value/NN)
# (S
#   The/DT
#   output/NN
#   from/IN
#   the/DT
#   above/JJ
#   program/NN
#   will/MD
#   be/VB
#   shown/VBN
#   as/IN
#   follows/VBZ
#   2/CD
#   2.78/CD
#   3/CD
#   5.56/CD
#   4/CD
#   8.33/CD
#   5/CD
#   11.11/CD
#   6/CD
#   13.89/CD
#   7/CD
#   16.67/CD
#   8/CD
#   13.89/CD
#   9/CD
#   11.11/CD
#   10/CD
#   8.33/CD
#   11/CD
#   5.56/CD
#   12/CD
#   2.78/CD
#   We/PRP
#   will/MD
#   use/VB
#   the/DT
#   following/JJ
#   type/NN
#   styles/NNS
#   for/IN
#   references/NNS
#   to/TO
#   a/DT
#   specific/JJ
#   Class/NNP
#   method/NN
#   or/CC
#   variable/JJ)
# (S
#   (PERSON Tip/NNP)
#   (ORGANIZATION Tips/NNP Look/NNP Like/IN This/DT)
#   There/EX
#   will/MD
#   be/VB
#   design/JJ
#   tips/NNS
#   and/CC
#   warnings/NNS
#   in/IN
#   the/DT
#   material/NN
#   for/IN
#   each/DT
#   exercise/NN)
# (S
#   These/DT
#   reflect/VBP
#   considerations/NNS
#   and/CC
#   lessons/NNS
#   learned/VBD
#   that/IN
#   aren/JJ
#   ’/NNP
#   t/NN
#   typically/RB
#   clear/JJ
#   to/TO
#   starting/VBG
#   OO/NNP
#   designers/NNS)
# (S ©/RB Copyright/NNP 2015/CD (PERSON Steven/NNP F./NNP Lott/NNP))
# (S
#   Created/VBN
#   using/VBG
#   Sphinx/NNP
#   1.3.1./CD
#   index/NN
#   modules/NNS
#   next/IN
#   previous/JJ
#   Building/NNP
#   Skills/NNP
#   in/IN
#   Object-Oriented/NNP
#   Design/NNP
#   3.1/CD
#   documentation/NN
#   »/JJ
#   Foundations/NNP
#   We/PRP
#   ’/VBP
#   ll/JJ
#   set/VB
#   our/PRP$
#   goal/NN
#   by/IN
#   presenting/VBG
#   several/JJ
#   elements/NNS
#   that/WDT
#   make/VBP
#   up/RP
#   a/DT
#   complete/JJ
#   Problem/NNP
#   Statement/NNP
#   a/DT
#   context/NN
#   in/IN
#   which/WDT
#   the/DT
#   problem/NN
#   arises/VBZ
#   the/DT
#   problem/NN
#   the/DT
#   forces/NNS
#   that/WDT
#   influence/VBP
#   the/DT
#   choice/NN
#   of/IN
#   solution/NN
#   the/DT
#   solution/NN
#   that/WDT
#   balances/VBZ
#   the/DT
#   forces/NNS
#   and/CC
#   some/DT
#   consequences/NNS
#   of/IN
#   the/DT
#   chosen/NN
#   solution/NN)
# (S
#   Based/VBN
#   on/IN
#   the/DT
#   problem/NN
#   statement/NN
#   we/PRP
#   ’/VBP
#   ll/JJ
#   present/JJ
#   the/DT
#   high-level/NN
#   use/NN
#   case/NN
#   that/IN
#   this/DT
#   software/NN
#   implements/NNS)
# (S This/DT will/MD be/VB Our/PRP$ Simulation/NNP Application/NNP)
# (S
#   In/IN
#   (ORGANIZATION Solution/NNP)
#   Approach/NNP
#   we/PRP
#   ’/VBP
# ...
#   a/DT
#   very/RB
#   basic/JJ
#   wheel/NN
#   first/RB
#   and/CC
#   work/VB
#   on/IN
#   the/DT
#   bin-building/NN
#   algorithms/NN
#   later/RB)
# (S
#   It/PRP
#   ’/VBZ
#   s/RB
#   often/RB
#   simplest/JJS
#   to/TO
#   build/VB
#   a/DT
#   class/NN
#   incrementally/RB)
# (S
#   This/DT
#   is/VBZ
#   an/DT
#   example/NN
#   where/WRB
#   the/DT
#   overall/JJ
#   structure/NN
#   is/VBZ
#   pretty/JJ
#   simple/JJ
#   but/CC
#   some/DT
#   details/NNS
#   are/VBP
#   rather/RB
#   complex/JJ)
# (S
#   (PERSON Wheel/NNP)
#   Design/NNP
#   class/NN
#   (PERSON Wheel/NNP Wheel/NNP)
#   contains/VBZ
#   the/DT
#   38/CD
#   individual/JJ
#   bins/NNS
#   on/IN
#   a/DT
#   Roulette/NNP
#   wheel/NN
#   plus/CC
#   a/DT
#   random/JJ
#   number/NN
#   generator/NN)
# (S
#   It/PRP
#   can/MD
#   select/VB
#   a/DT
#   Bin/NNP
#   at/IN
#   random/NN
#   simulating/VBG
#   a/DT
#   spin/NN
#   of/IN
#   the/DT
#   (ORGANIZATION Roulette/NNP)
#   wheel/NN)
# (S
#   Fields/NNS
#   Wheel.bins/VBZ
#   Contains/VBZ
#   the/DT
#   individual/JJ
#   Bin/NNP
#   instances/NNS)
# (S This/DT is/VBZ a/DT tuple/NN of/IN 38/CD elements/NNS)
# (S
#   This/DT
#   can/MD
#   be/VB
#   built/VBN
#   with/IN
#   tuple/JJ
#   Bin/NNP
#   for/IN
#   i/NN
#   in/IN
#   range/NN
#   38/CD
#   Wheel.rng/NNP
#   A/NNP
#   random/NN
#   number/NN
#   generator/NN
#   to/TO
#   use/VB
#   to/TO
#   select/VB
#   a/DT
#   Bin/NNP
#   from/IN
#   the/DT
#   bins/NNS
#   collection/NN)
# (S
#   Because/IN
#   of/IN
#   the/DT
#   central/JJ
#   importance/NN
#   of/IN
#   this/DT
#   particular/JJ
#   source/NN
#   of/IN
#   randomness/NN
#   it/PRP
#   seems/VBZ
#   sensible/JJ
#   to/TO
#   isolate/VB
#   it/PRP
#   from/IN
#   any/DT
#   other/JJ
#   processing/NN
#   that/WDT
#   might/MD
#   need/VB
#   random/JJ
#   numbers/NNS)
# (S
#   We/PRP
#   can/MD
#   then/RB
#   set/VB
#   a/DT
#   seed/NN
#   value/NN
#   using/VBG
#   os.urandom/NN
#   or/CC
#   specific/JJ
#   values/NNS
#   for/IN
#   testing/VBG)
# (S
#   Constructors/NNS
#   Wheel.__init__/NNP
#   self/PRP
#   Creates/VBZ
#   a/DT
#   new/JJ
#   wheel/NN
#   with/IN
#   38/CD
#   empty/JJ
#   Bins/NNS)
# (S
#   It/PRP
#   will/MD
#   also/RB
#   create/VB
#   a/DT
#   new/JJ
#   random/JJ
#   number/NN
#   generator/NN
#   instance/NN)
# (S
#   At/IN
#   the/DT
#   present/JJ
#   time/NN
#   this/DT
#   does/VBZ
#   not/RB
#   do/VB
#   the/DT
#   full/JJ
#   initialization/NN
#   of/IN
#   the/DT
#   Bins/NNS)
# (S
#   We/PRP
#   ’/VBP
#   ll/JJ
#   rework/NN
#   this/DT
#   in/IN
#   a/DT
#   future/NN
#   exercise/NN)
# (S
#   (PERSON Methods/NNS)
#   Bin.addOutcome/NNP
#   number/NN
#   outcome/NN
#   Adds/NNP
#   the/DT
#   given/VBN
#   (PERSON Outcome/NNP)
#   to/TO
#   the/DT
#   (ORGANIZATION Bin/NNP)
#   with/IN
#   the/DT
#   given/VBN
#   number/NN)
# (S
#   Parameters/NNS
#   bin/VBP
#   int/JJ
#   –/NNP
#   bin/NN
#   number/NN
#   in/IN
#   the/DT
#   range/NN
#   zero/NN
#   to/TO
#   37/CD
#   inclusive/NN)
# (S
#   outcome/JJ
#   Outcome/NNP
#   –/NNP
#   The/DT
#   Outcome/NNP
#   to/TO
#   add/VB
#   to/TO
#   this/DT
#   Bin/NNP
#   Bin.next/NNP
#   →/NNP
#   Bin/NNP
#   Generates/VBZ
#   a/DT
#   random/JJ
#   number/NN
#   between/IN
#   0/CD
#   and/CC
#   37/CD
#   and/CC
#   returns/VBZ
#   the/DT
#   randomly/RB
#   selected/VBN
#   (PERSON Bin/NNP))
# (S
#   The/DT
#   Random.choice/NNP
#   function/NN
#   of/IN
#   the/DT
#   random/NN
#   module/NN
#   will/MD
#   select/VB
#   one/CD
#   of/IN
#   the/DT
#   available/JJ
#   Bin/NNP
#   s/NN
#   from/IN
#   the/DT
#   bins/NNS
#   list/NN)
# (S
#   Returns/NNS
#   A/NNP
#   Bin/NNP
#   selected/VBN
#   at/IN
#   random/NN
#   from/IN
#   the/DT
#   wheel/NN)
# (S
#   (GPE Return/NNP)
#   type/NN
#   (PERSON Bin/NNP)
#   Bin.get/NNP
#   bin/NN
#   →/NNP
#   Bin/NNP
#   Returns/NNP
#   the/DT
#   given/VBN
#   (PERSON Bin/NNP)
#   from/IN
#   the/DT
#   internal/JJ
#   collection/NN)
# (S
#   Parameters/NNS
#   bin/VBP
#   int/JJ
#   –/NNP
#   bin/NN
#   number/NN
#   in/IN
#   the/DT
#   range/NN
#   zero/NN
#   to/TO
#   37/CD
#   inclusive/NN)
# (S Returns/VBZ The/DT requested/JJ Bin/NNP)
# (S
#   (GPE Return/NNP)
#   type/NN
#   (PERSON Bin/NNP Test/NNP)
#   Setup/NNP
#   We/PRP
#   need/VBP
#   a/DT
#   controlled/JJ
#   kind/NN
#   of/IN
#   random/JJ
#   number/NN
#   generation/NN
#   for/IN
#   testing/VBG
#   purposes/NNS)
# (S
#   This/DT
#   is/VBZ
#   done/VBN
#   with/IN
#   tests/NNS
#   that/WDT
#   look/VBP
#   like/IN
#   the/DT
#   following/JJ
#   (PERSON Test/NNP Outline/NNP)
#   class/NN
#   GIVEN_Wheel_WHEN_next_THEN_random_choice/NNP
#   unittest.TestCase/NN
#   def/NN
#   setUp/NN
#   self/PRP
#   self.wheel=/VBP
#   (PERSON Wheel/NNP)
#   self.wheel.rng.seed/VBD
#   1/CD
#   def/NN
#   (ORGANIZATION runTest/NN)
#   self/NN
#   etc/NN)
# (S
#   The/DT
#   values/NNS
#   delivered/VBN
#   from/IN
#   this/DT
#   seeded/JJ
#   random/NN
#   number/NN
#   generator/NN
#   can/MD
#   be/VB
#   seen/VBN
#   from/IN
#   this/DT
#   experiment/NN)
# (S
#   Fixed/VBN
#   pseudo-random/JJ
#   sequence/NN
#   x/NN
#   random.Random/NN
#   x.seed/VBD
#   1/CD
#   x.randint/NN
#   0,37/CD
#   for/IN
#   i/NN
#   in/IN
#   range/NN
#   10/CD
#   8/CD
#   36/CD
#   4/CD
#   16/CD
#   7/CD
#   31/CD
#   28/CD
#   30/CD
#   24/CD
#   13/CD
#   This/DT
#   allows/VBZ
#   us/PRP
#   to/TO
#   predict/VB
#   the/DT
#   output/NN
#   from/IN
#   the/DT
#   Wheel.next/NNP
#   method/NN)
# (S
#   (PERSON Wheel/NNP)
#   Deliverables/NNP
#   There/EX
#   are/VBP
#   three/CD
#   deliverables/NNS
#   for/IN
#   this/DT
#   exercise/NN)
# (S
#   The/DT
#   new/JJ
#   class/NN
#   and/CC
#   the/DT
#   unit/NN
#   test/NN
#   will/MD
#   have/VB
#   (PERSON Python/NNP)
#   docstrings/NNS)
# (S The/DT Wheel/NNP class/NN)
# (S
#   A/DT
#   class/NN
#   which/WDT
#   performs/VBZ
#   a/DT
#   unit/NN
#   test/NN
#   of/IN
#   building/VBG
#   the/DT
#   Wheel/NNP
#   class/NN)
# (S
#   The/DT
#   unit/NN
#   test/NN
#   should/MD
#   create/VB
#   several/JJ
#   instances/NNS
#   of/IN
#   Outcome/NNP
#   two/CD
#   instances/NNS
#   of/IN
#   (PERSON Bin/NNP)
#   and/CC
#   an/DT
#   instance/NN
#   of/IN
#   (GPE Wheel/NNP))
# (S
#   The/DT
#   unit/NN
#   test/NN
#   should/MD
#   establish/VB
#   that/IN
#   (PERSON Bins/NNS)
#   can/MD
#   be/VB
#   added/VBN
#   to/TO
#   the/DT
#   Wheel/NNP)
# (S
#   A/DT
#   class/NN
#   which/WDT
#   tests/VBZ
#   the/DT
#   Wheel/NNP
#   class/NN
#   by/IN
#   selecting/VBG
#   “/JJ
#   random/JJ
#   ”/NN
#   values/NNS
#   from/IN
#   a/DT
#   Wheel/NNP
#   object/NN
#   using/VBG
#   a/DT
#   fixed/JJ
#   seed/NN
#   value/NN)
# (S ©/RB Copyright/NNP 2015/CD (PERSON Steven/NNP F./NNP Lott/NNP))
# (S
#   Created/VBN
#   using/VBG
#   Sphinx/NNP
#   1.3.1./CD
#   index/NN
#   modules/NNS
#   next/IN
#   previous/JJ
#   Building/NNP
#   Skills/NNP
#   in/IN
#   Object-Oriented/NNP
#   Design/NNP
#   3.1/CD
#   documentation/NN
#   »/NNP
#   Bin/NNP
#   Builder/NNP
#   Class/NNP
#   We/PRP
#   ’/VBP
#   ll/JJ
#   look/NN
#   at/IN
#   the/DT
#   question/NN
#   of/IN
#   filling/NN
#   in/IN
#   the/DT
#   Outcomes/NNP
#   in/IN
#   each/DT
#   Bin/NNP
#   of/IN
#   the/DT
#   Wheel/NNP)
# (S
#   The/DT
#   (ORGANIZATION Bin/NNP Builder/NNP Analysis/NNP)
#   section/NN
#   will/MD
#   address/VB
#   the/DT
#   various/JJ
#   outcomes/NNS
#   in/IN
#   details/NNS)
# (S
#   In/IN
#   (GPE Bin/NNP)
#   Builder/NNP
#   Algorithms/NNP
#   we/PRP
#   ’/VBP
#   ll/JJ
#   look/NN
#   at/IN
#   eight/CD
#   algorithms/NNS
#   for/IN
#   allocating/VBG
#   appropriate/JJ
#   outcomes/NNS
#   to/TO
#   appropriate/VB
#   bins/NNS
#   of/IN
#   the/DT
#   wheel/NN)
# (S
#   The/DT
#   (ORGANIZATION BinBuilder/NNP)
#   Design/NNP
#   section/NN
#   will/MD
#   present/VB
#   the/DT
#   detailed/JJ
#   design/NN
#   for/IN
#   this/DT
#   class/NN)
# (S
#   In/IN
#   (GPE Bin/NNP)
#   Builder/NNP
#   Deliverables/NNP
#   we/PRP
#   ’/VBP
#   ll/JJ
#   define/NN
#   the/DT
#   specific/NN
#   deliverables/NNS)
# (S
#   In/IN
#   (ORGANIZATION Internationalization/NNP)
#   and/CC
#   Localization/NNP
#   we/PRP
#   ’/VBP
#   ll/JJ
#   identify/VB
#   some/DT
#   considerations/NNS
#   for/IN
#   providing/VBG
#   local/JJ
#   language/NN
#   names/NNS
#   for/IN
#   the/DT
#   outcomes/NNS)
# (S
#   (PERSON Bin/NNP)
#   (PERSON Builder/NNP Analysis/NNP)
#   It/PRP
#   is/VBZ
#   clear/JJ
#   that/IN
#   enumerating/VBG
#   each/DT
#   Outcome/NN
#   in/IN
#   the/DT
#   38/CD
#   Bins/NNS
#   by/IN
#   hand/NN
#   is/VBZ
#   a/DT
#   tedious/JJ
#   undertaking/NN)
# (S
#   Most/JJS
#   Bins/NNS
#   contain/VBP
#   about/IN
#   fourteen/JJ
#   individual/JJ
#   Outcomes/NNS)
# (S
#   We/PRP
#   need/VBP
#   a/DT
#   one-time-only/JJ
#   algorithm/NN
#   to/TO
#   do/VB
#   this/DT
#   job/NN)
# (S
#   It/PRP
#   is/VBZ
#   often/RB
#   helpful/JJ
#   to/TO
#   create/VB
#   a/DT
#   class/NN
#   that/WDT
#   is/VBZ
#   used/VBN
#   to/TO
#   build/VB
#   an/DT
#   instance/NN
#   of/IN
#   another/DT
#   class/NN)
# (S
#   This/DT
#   is/VBZ
#   a/DT
#   design/NN
#   pattern/NN
#   sometimes/RB
#   called/VBD
#   a/DT
#   Builder/NN)
# (S
#   We/PRP
#   ’/VBP
#   ll/JJ
#   design/NN
#   an/DT
#   object/NN
#   that/WDT
#   builds/VBZ
#   the/DT
#   various/JJ
#   Bins/NNP
#   and/CC
#   assigns/VB
#   them/PRP
#   to/TO
#   the/DT
#   Wheel/NNP)
# (S
#   This/DT
#   will/MD
#   fill/VB
#   the/DT
#   need/NN
#   left/VBD
#   open/JJ
#   in/IN
#   the/DT
#   Wheel/NNP
#   Class/NN)
# (S
#   Additionally/RB
#   we/PRP
#   note/VBP
#   that/IN
#   the/DT
#   complex/JJ
#   algorithms/NN
#   to/TO
#   construct/VB
#   the/DT
#   Bins/NNS
#   are/VBP
#   only/RB
#   tangential/JJ
#   to/TO
#   the/DT
#   operation/NN
#   of/IN
#   the/DT
#   Wheel/NNP
#   object/NN)
# (S
#   Because/IN
#   these/DT
#   are/VBP
#   not/RB
#   essential/JJ
#   to/TO
#   the/DT
#   design/NN
#   of/IN
#   the/DT
#   Wheel/NNP
#   class/NN
#   we/PRP
#   find/VBP
#   it/PRP
#   is/VBZ
#   often/RB
#   helpful/JJ
#   to/TO
#   segregate/VB
#   the/DT
#   rather/RB
#   complex/JJ
#   builder/NN
#   methods/NNS
#   into/IN
#   a/DT
#   separate/JJ
#   class/NN)
# (S
#   The/DT
#   (ORGANIZATION BinBuilder/NNP)
#   class/NN
#   will/MD
#   have/VB
#   a/DT
#   method/NN
#   that/WDT
#   enumerates/VBZ
#   the/DT
#   contents/NNS
#   of/IN
#   each/DT
#   of/IN
#   the/DT
#   36/CD
#   number/NN
#   Bins/NNP
#   building/VBG
#   the/DT
#   individual/JJ
#   Outcome/NNP
#   instances/NNS)
# (S
#   We/PRP
#   can/MD
#   then/RB
#   assign/VB
#   these/DT
#   Outcome/NNP
#   objects/NNS
#   to/TO
#   the/DT
#   (ORGANIZATION Bins/NNP)
#   of/IN
#   a/DT
#   Wheel/NNP
#   instance/NN)
# (S
#   We/PRP
#   will/MD
#   use/VB
#   a/DT
#   number/NN
#   of/IN
#   steps/NNS
#   to/TO
#   create/VB
#   the/DT
#   various/JJ
#   types/NNS
#   of/IN
#   (GPE Outcomes/NNP)
#   and/CC
#   depend/VB
#   on/IN
#   the/DT
#   Wheel/NNP
#   to/TO
#   assign/VB
#   each/DT
#   Outcome/NNP
#   object/NN
#   to/TO
#   the/DT
#   correct/JJ
#   Bin/NNP)
# (S
#   The/DT
#   (ORGANIZATION Roulette/NNP Outcomes/NNP)
#   Looking/NNP
#   at/IN
#   the/DT
#   (ORGANIZATION Available/JJ Bets/NNS)
#   in/IN
#   (GPE Roulette/NNP)
#   gives/VBZ
#   us/PRP
#   a/DT
#   number/NN
#   of/IN
#   geometric/JJ
#   rules/NNS
#   for/IN
#   determining/VBG
#   the/DT
#   various/JJ
#   Outcomes/NNS
#   that/WDT
#   are/VBP
#   combinations/NNS
#   of/IN
#   individual/JJ
#   numbers/NNS)
# (S
#   These/DT
#   rules/NNS
#   apply/VBP
#   to/TO
#   the/DT
#   numbers/NNS
#   from/IN
#   one/CD
#   to/TO
#   thirty-six/VB)
# (S
#   A/DT
#   different/JJ
#   –/NN
#   and/CC
#   much/JJ
#   simpler/NN
#   –/NNP
#   set/NN
#   of/IN
#   rules/NNS
#   applies/NNS
#   to/TO
#   0/CD
#   and/CC
#   00/CD)
# (S
#   First/RB
#   we/PRP
#   ’/VBP
#   ll/JJ
#   survey/NN
#   the/DT
#   table/NN
#   geometry/NN
#   then/RB
#   we/PRP
#   ’/VBP
#   ll/JJ
#   develop/NN
#   specific/JJ
#   algorithms/NN
#   for/IN
#   each/DT
#   kind/NN
#   of/IN
#   bet/NN)
# (S (GPE Split/NNP) Bets/NNS)
# (S
#   Each/DT
#   number/NN
#   is/VBZ
#   adjacent/JJ
#   to/TO
#   two/CD
#   three/CD
#   or/CC
#   four/CD
#   other/JJ
#   numbers/NNS)
# (S
#   The/DT
#   four/CD
#   corners/NNS
#   1/CD
#   3/CD
#   34/CD
#   and/CC
#   36/CD
#   only/RB
#   participate/VB
#   in/IN
#   two/CD
#   split/JJ
#   bets/NNS
#   1-2/JJ
#   and/CC
#   1-4/JJ
#   2-3/JJ
#   and/CC
#   3-6/JJ
#   34-35/JJ
#   and/CC
#   31-34/JJ
#   35-36/JJ
#   and/CC
#   33-36/JJ)
# (S
#   The/DT
#   center/JJ
#   column/NN
#   of/IN
#   numbers/NNS
#   5/CD
#   8/CD
#   11/CD
#   .../:
#   32/CD
#   each/DT
#   participate/NN
#   in/IN
#   four/CD
#   split/NN
#   bets/NNS
#   with/IN
#   the/DT
#   surrounding/VBG
#   numbers/NNS)
# (S
#   The/DT
#   remaining/VBG
#   “/NN
#   edge/NN
#   ”/NNP
#   numbers/NNS
#   participate/VBP
#   in/IN
#   three/CD
#   split/NN
#   bets/NNS)
# (S
#   While/IN
#   this/DT
#   is/VBZ
#   moderately/RB
#   complex/JJ
#   the/DT
#   bulk/NN
#   of/IN
#   the/DT
#   layout/NN
#   from/IN
#   4/CD
#   to/TO
#   32/CD
#   can/MD
#   be/VB
#   handled/VBN
#   with/IN
#   a/DT
#   simple/JJ
#   rule/NN
#   to/TO
#   distinguish/VB
#   the/DT
#   center/JJ
#   column/NN
#   from/IN
#   the/DT
#   edge/NN
#   columns/NN)
# (S
#   The/DT
#   ends/NNS
#   1/CD
#   2/CD
#   3/CD
#   and/CC
#   34/CD
#   35/CD
#   36/CD
#   are/VBP
#   a/DT
#   little/JJ
#   more/JJR
#   complex/JJ)
# (S (GPE Street/NNP) Bets/NNS)
# (S
#   Each/DT
#   number/NN
#   is/VBZ
#   a/DT
#   member/NN
#   of/IN
#   one/CD
#   of/IN
#   the/DT
#   twelve/JJ
#   street/NN
#   bets/NNS)
# (S (GPE Corner/NNP) Bets/NNS)
# (S
#   Each/DT
#   number/NN
#   is/VBZ
#   a/DT
#   member/NN
#   of/IN
#   one/CD
#   two/CD
#   or/CC
#   four/CD
#   corner/NN
#   bets/NNS)
# (S
#   As/IN
#   with/IN
#   split/NN
#   bets/NNS
#   the/DT
#   bulk/NN
#   of/IN
#   the/DT
#   layout/NN
#   can/MD
#   be/VB
#   handled/VBN
#   with/IN
#   a/DT
#   simple/JJ
#   rule/NN
#   to/TO
#   distinguish/VB
#   the/DT
#   column/NN
#   and/CC
#   hence/RB
#   the/DT
#   “/JJ
#   corners/NNS
#   ”/VBP)
# (S
#   A/DT
#   number/NN
#   in/IN
#   the/DT
#   center/NN
#   column/NN
#   5/CD
#   8/CD
#   11/CD
#   .../:
#   32/CD
#   is/VBZ
#   a/DT
#   member/NN
#   of/IN
#   four/CD
#   corners/NNS)
# (S
#   All/DT
#   of/IN
#   the/DT
#   numbers/NNS
#   along/IN
#   an/DT
#   edge/NN
#   are/VBP
#   members/NNS
#   of/IN
#   two/CD
#   corners/NNS)
# (S
#   For/IN
#   example/NN
#   4/CD
#   is/VBZ
#   part/NN
#   of/IN
#   1-2-4-5/JJ
#   and/CC
#   4-5-7-8/JJ)
# (S
#   At/IN
#   the/DT
#   ends/NNS
#   1/CD
#   3/CD
#   and/CC
#   34/CD
#   36/CD
#   we/PRP
#   see/VBP
#   outcomes/NNS
#   that/IN
#   members/NNS
#   of/IN
#   just/RB
#   one/CD
#   corner/JJR
#   each/DT)
# (S (GPE Line/NNP) Bets/NNS)
# (S
#   Six/CD
#   numbers/NNS
#   comprise/VBP
#   a/DT
#   line/NN
#   each/DT
#   number/NN
#   is/VBZ
#   a/DT
#   member/NN
#   of/IN
#   one/CD
#   or/CC
#   two/CD
#   lines/NNS)
# (S
#   The/DT
#   ends/NNS
#   1/CD
#   2/CD
#   3/CD
#   and/CC
#   34/CD
#   35/CD
#   36/CD
#   are/VBP
#   each/DT
#   part/NN
#   of/IN
#   a/DT
#   single/JJ
#   line/NN)
# (S
#   The/DT
#   remaining/VBG
#   10/CD
#   rows/NNS
#   are/VBP
#   each/DT
#   part/NN
#   of/IN
#   two/CD
#   lines/NNS)
# (S (GPE Dozen/NNP) Bets/NNS)
# (S
#   Each/DT
#   number/NN
#   is/VBZ
#   a/DT
#   member/NN
#   of/IN
#   one/CD
#   of/IN
#   the/DT
#   three/CD
#   dozens/NNS)
# (S
#   The/DT
#   three/CD
#   ranges/NNS
#   are/VBP
#   from/IN
#   1/CD
#   to/TO
#   12/CD
#   13/CD
#   to/TO
#   24/CD
#   and/CC
#   25/CD
#   to/TO
#   36/CD
#   making/VBG
#   it/PRP
#   very/RB
#   easy/JJ
#   to/TO
#   associate/VB
#   numbers/NNS
#   and/CC
#   ranges/NNS)
# (S (GPE Column/NNP) Bets/NNS)
# (S
#   Each/DT
#   number/NN
#   is/VBZ
#   a/DT
#   member/NN
#   of/IN
#   one/CD
#   of/IN
#   the/DT
#   three/CD
#   columns/NN)
# (S
#   Each/DT
#   of/IN
#   the/DT
#   columns/NN
#   has/VBZ
#   a/DT
#   number/NN
#   numeric/JJ
#   relationship/NN)
# (S The/DT values/NNS are/VBP and/CC where/WRB)
# (S The/DT Even-Money/NNP Bets/NNS)
# (S
#   These/DT
#   include/VBP
#   (PERSON Red/NNP Black/NNP)
#   Even/NNP
#   Odd/NNP
#   High/NNP
#   Low/NNP)
# (S
#   Each/DT
#   number/NN
#   on/IN
#   the/DT
#   layout/NN
#   will/MD
#   be/VB
#   associated/VBN
#   with/IN
#   three/CD
#   of/IN
#   the/DT
#   six/CD
#   possible/JJ
#   even/RB
#   money/NN
#   Outcomes/NNS)
# (S
#   One/CD
#   way/NN
#   to/TO
#   handle/VB
#   these/DT
#   is/VBZ
#   to/TO
#   create/VB
#   the/DT
#   six/CD
#   individual/JJ
#   Outcome/NNP
#   instances/NNS)
# (S
#   For/IN
#   each/DT
#   number/NN
#   n/IN
#   we/PRP
#   can/MD
#   write/VB
#   a/DT
#   suite/NN
#   of/IN
#   if-statements/NNS
#   to/TO
#   determine/VB
#   which/WDT
#   of/IN
#   the/DT
#   Outcome/NNP
#   objects/NNS
#   are/VBP
#   associated/VBN
#   with/IN
#   the/DT
#   given/VBN
#   number/NN)
# (S
#   The/DT
#   (ORGANIZATION Bins/NNP)
#   for/IN
#   zero/NN
#   and/CC
#   double/JJ
#   zero/NN
#   are/VBP
#   just/RB
#   special/JJ
#   cases/NNS)
# (S
#   Each/DT
#   of/IN
#   these/DT
#   Bins/NNP
#   has/VBZ
#   a/DT
#   straight/JJ
#   number/NN
#   bet/VBD
#   (PERSON Outcome/NNP)
#   plus/CC
#   the/DT
#   “/NNP
#   Five/NNP
#   Bet/NNP
#   ”/NNP
#   Outcome/NNP
#   00-0-1-2-3/CD
#   which/WDT
#   pays/VBZ
#   6:1/CD)
# (S
#   One/CD
#   other/JJ
#   thing/NN
#   we/PRP
#   ’/VBP
#   ll/JJ
#   probably/RB
#   want/VBP
#   are/VBP
#   handy/JJ
#   names/NNS
#   for/IN
#   the/DT
#   various/JJ
#   kinds/NNS
#   of/IN
#   odds/NNS)
# (S
#   We/PRP
#   might/MD
#   want/VB
#   to/TO
#   define/VB
#   a/DT
#   collection/NN
#   of/IN
#   constants/NNS
#   for/IN
#   this/DT)
# (S
#   While/IN
#   can/MD
#   define/VB
#   an/DT
#   Outcome/NN
#   as/IN
#   (PERSON Outcome/NNP)
#   ``/``
#   Number/NNP
#   1/CD
#   ''/''
#   35/CD
#   this/DT
#   is/VBZ
#   a/DT
#   little/JJ
#   opaque/NN)
# (S
#   A/DT
#   slightly/RB
#   nicer/JJ
#   form/NN
#   is/VBZ
#   (PERSON Outcome/NNP)
#   ``/``
#   Number/NNP
#   1/CD
#   ''/''
#   RouletteGame.StraightBet/NN)
# (S
#   The/DT
#   payouts/NNS
#   are/VBP
#   specific/JJ
#   to/TO
#   a/DT
#   game/NN
#   not/RB
#   general/JJ
#   features/NNS
#   of/IN
#   all/DT
#   Outcomes/NNS)
# (S
#   They/PRP
#   properly/RB
#   belong/VBP
#   in/IN
#   some/DT
#   kind/NN
#   of/IN
#   game/NN
#   related/JJ
#   class/NN)
# (S
#   We/PRP
#   haven/VBP
#   ’/JJ
#   t/NN
#   designed/VBN
#   the/DT
#   game/NN
#   yet/RB
#   but/CC
#   we/PRP
#   can/MD
#   provide/VB
#   a/DT
#   simplified/JJ
#   class/NN
#   which/WDT
#   only/RB
#   contains/VBZ
#   these/DT
#   odds/NNS
#   definitions/NNS)

# %% [markdown]
# ## NER with custom patterns

# %%
# custom grammar: adjective (optional, multiple) and proper noun (singular/plural)
grammar = "NP: {<JJ>*<NN|NNS>}"
cp = nltk.RegexpParser(grammar)

custom_parsed_sentences = []
for t in tagged:    
    result = cp.parse(t)
    custom_parsed_sentences.append(result)

# %% [markdown]
# ## Implement your custom entity classification

# %%
import wikipedia
    
# extract wanted entities from the tree and put them in a list of queries
queries = []
for s in custom_parsed_sentences:
    for chunk in s:
        if (isinstance(chunk, nltk.tree.Tree) and chunk.label() == 'NP'):
            text = " ".join([word for word, tag in chunk.leaves()])
            queries.append(text)
            # print(text)
            
# remove duplicate entries by using "set"
queries = list(set(queries))

# %%
# get results from wikipedia for the term/query
def getWikiInfo(query):
    # search for the sentence on wikipedia, e.g. query = "A car is a wheeled motor vehicle used for transportation."
    results = wikipedia.search(query)
    
    if results:
        try:
            # print the first sentence of the first search result
            return (wikipedia.summary(results[0], sentences=1))
        except wikipedia.exceptions.DisambiguationError as e:
            # there are multiple results for this term, print the first option:
            try:
                return wikipedia.summary(e.options[0], sentences=1)
            except wikipedia.exceptions.DisambiguationError as e:
                # we cannot get any result without further choice, end
                pass

# %%
# categorize the entities in a sentence with own grammar
def categorizeSentence(s):
    tokens = nltk.word_tokenize(s)
    tokens_no_punc = [token for token in tokens if token not in punctuation]
    tagged = nltk.pos_tag(tokens_no_punc)

    # detect pattern “… is/VBZ a/DT free/JJ online/NN encyclopedia/NN …“
    grammar = "NP: {<VBZ><DT><JJ>*<NN|NNS>+}"
    cp = nltk.RegexpParser(grammar)

    result = cp.parse(tagged)
    return(result)

# %%
# extract text (only "NN") from the supplied tree
def getCategoryText(tree):
    for chunk in tree:
        if (isinstance(chunk, nltk.tree.Tree) and chunk.label() == 'NP'):
            result = ""
            for t in chunk:
                if t[1].startswith("NN"):
                    result += t[0] + " "

            return result.strip()

# %%
# for all custom entities in the text, extract info from wiki, categorize it and print it ("None" is unknown category)
for q in queries:
    wikInfo = getWikiInfo(q)
    if wikInfo:
        category = categorizeSentence(wikInfo)
        catText = getCategoryText(category)
    else:
        catText = "None"
    print(q, ": ", catText, "\n")
# Out:
# block :  term
#
# Available Bets :  online
#
# problems :  None
#
# multiplication :  None
#
# card :  None
#
# complete analyses :  laboratory instrument
#
# trivial :  None
#
# random.Random :  None
#
# different points :  None
#
# individual exercises :  None
#
# triples :  act
#
# synonyms adaptation :  genus
#
# external customer :  recipient
#
# other classes :  term
#
# red ” :  color
#
# related numbers :  sum
#
# values :  degree
#
# strategy :  plan
#
# version :  process
#
# right things :  None
#
# traditional procedural programming :  design principle
#
# n combo :  panel van
#
# circles :  simple
#
# Considerations :  concept
#
# money :  item
#
# technology :  collection
#
# abstract possibility :  None
#
# dice game :  None
#
# careful enumeration :  dispersing prism
#
# small ball :  term
#
# sequential collection :  None
#
# seed :  plant
#
# few techniques :  time management method
#
# Blackjack :  None
#
# simple rule :  sitcom comedy television show
#
# distinct layers :  role
#
# exclusive users :  drama series
#
# hash codes :  function
#
# house :  building
#
# processing :  set
#
# primary objective :  idea
#
# layout :  part
#
# other → boolean :  branch
#
# matter :  substance
#
# wagering :  wagering
#
# built-in data :  design company
#
# Problem :  None
#
# ll amplify :  list
#
# few responsibilities :  form
#
# individual spin :  form
#
# many bets :  casino game
#
# object constructors :  type
#
# views :  protocol
#
# range :  None
#
# invent new strategies :  formulation
#
# program :  process
#
# odds:1 :  None
#
# scenario :  scenario
#
# practical matter :  health care law
#
# parts :  actor composer
#
# available collections :  None
#
# discrepency :  difference
#
# customers :  recipient
#
# many respects :  None
#
# experiences :  knowledge
#
# fronzenset :  None
#
# problem-oriented classes :  acronym
#
# favorable state :  state
#
# map :  depiction
#
# python3 :  high-level programming language
#
# general ways :  difference
#
# actual person :  None
#
# ll develop :  rapper actor author
#
# 1-3-2-6 system :  spreadsheet program
#
# speed :  magnitude
#
# next numbers :  None
#
# casino.craps :  theory
#
# course :  direction
#
# Testability :  None
#
# loss :  term
#
# parallel arrays :  form
#
# overall statistical analysis :  branch
#
# single actor :  person
#
# complex exercises :  process
#
# Methods :  body
#
# basic wheel :  organization
#
# something :  None
#
# preliminary :  term
#
# several fit-and-finish issues :  None
#
# effect :  consequence
#
# run-time overhead :  combination
#
# ll notice :  television series
#
# ll avoid :  degree
#
# third part :  incarnation
#
# languages :  system
#
# Table :  item
#
# sample :  set
#
# concepts :  None
#
# odd choice :  None
#
# designers :  person
#
# American version :  television comedy series
#
# many times :  song
#
# number :  object
#
# appendices :  addition
#
# universal feature :  animation studio
#
# trump :  None
#
# helpful :  property
#
# Complex algorithms :  specification
#
# other resource :  source
#
# other portions :  None
#
# spin :  None
#
# complete design :  arranging
#
# over-engineering :  application
#
# gamblers :  wagering
#
# resuse :  television series
#
# hands :  appendage
#
# basics :  None
#
# containers :  receptacle
#
# deadlines :  field
#
# language :  system
#
# defects :  None
#
# abstract level :  way
#
# procedural environments :  method
#
# inclusive :  operator
#
# various places :  game
#
# winAmount :  man
#
# technologies :  collection
#
# statistical analysis :  branch
#
# chosen :  None
#
# implementation :  realization
#
# complex structure :  manifold
#
# milestone :  None
#
# following “ :  None
#
# level :  elevation
#
# person :  None
#
# documetation :  None
#
# other programming :  software development technique
#
# next revision :  computer bus interface
#
# scalar vector :  projection
#
# several outcomes :  None
#
# bets :  wagering
#
# Message :  unit
#
# ” notecards :  None
#
# single bundle :  None
#
# respect :  feeling
#
# instructor :  person
#
# centers :  point
#
# handy names :  telephone
#
# encourage :  apostolate
#
# separate indexes :  data structure
#
# flexbility :  railway company
#
# encapsulation :  confinement
#
# player :  stage
#
# ll detail :  rapper actor author
#
# ll start :  rapper actor author
#
# event :  event
#
# summary :  summary
#
# patterns :  regularity
#
# keys :  low-elevation
#
# zerozero= :  skyscraper
#
# definition :  statement
#
# management :  administration
#
# full understanding :  None
#
# deliverable – documentation :  process
#
# ownership :  None
#
# nature :  None
#
# supplemental exerises :  None
#
# previous work :  Drop
#
# deals :  None
#
# simple equality :  problem
#
# skills :  ability
#
# states :  studio album
#
# complex calculation :  process
#
# simplest game :  None
#
# starting :  phase
#
# one :  number
#
# ll design :  rapper actor author
#
# few hours :  None
#
# added complication :  None
#
# itemization :  None
#
# architects :  person
#
# global instances :  trend
#
# additional topics :  relationship
#
# particular bin :  None
#
# Other times :  history programme
#
# excellent background :  Yeshiva
#
# adjacent street :  fashion
#
# subclass :  None
#
# waterfall approach :  None
#
# poker :  family
#
# operator :  post-grunge band
#
# overview :  None
#
# quick overview :  business
#
# examples :  None
#
# other thing :  None
#
# complaint :  document
#
# emphasis :  None
#
# attribute equality :  state
#
# overall view :  type
#
# advanced students :  learner
#
# question :  expression
#
# collision :  event
#
# new bet :  basic cable
#
# single object :  None
#
# payouts :  None
#
# techniques :  collection
#
# comma-separated values :  text file
#
# Returns :  profit
#
# complex operations :  installation
#
# expected results :  value
#
# job :  person
#
# multipliers :  None
#
# final form :  character
#
# subject matter :  None
#
# equality :  state
#
# operation :  body
#
# surface :  outermost
#
# short answer :  technique
#
# randomness :  lack
#
# propositions :  use
#
# consequences :  concept
#
# big-picture overview :  list
#
# ’ :  None
#
# ’ s decision-making :  None
#
# investigation :  science
#
# extension :  software engineering
#
# incremental learning :  method
#
# compare :  feature
#
# similar betting :  type
#
# Soapbox :  platform
#
# random number :  patterns
#
# inividual exercises :  None
#
# high-level :  town
#
# basis :  association
#
# complex builder :  design pattern
#
# technical considerations :  displacement lobe pump
#
# additional fields :  video game series
#
# distinct hash :  function
#
# Everything :  drama film
#
# thing :  None
#
# heads :  sports
#
# interim set :  title
#
# movie :  series
#
# Column :  element
#
# final value :  None
#
# columns :  element
#
# r :  symbol
#
# allocation :  data structure
#
# first chapter :  name
#
# notes :  pitch
#
# profusion :  song
#
# classes :  variety
#
# inappropriate solution :  None
#
# web presentation :  software package
#
# simple bet :  None
#
# detracts :  sin
#
# spins :  reaction
#
# non-OO design. ” :  None
#
# ideas :  list
#
# s :  letter
#
# concrete action :  material
#
# detailed specification :  document
#
# single class :  None
#
# appropriate kind :  kind
#
# following type :  None
#
# third win :  stallion
#
# compelling :  None
